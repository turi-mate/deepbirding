# %%
# !pip install kaggle
# !pip install pytorch-lightning
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2023.7.22)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4)
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-2.1.0-py3-none-any.whl (774 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.6/774.6 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (1.23.5)
# Requirement already satisfied: torch>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (2.1.0+cu118)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (4.66.1)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (2023.6.0)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning)
#   Downloading torchmetrics-1.2.0-py3-none-any.whl (805 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.2/805.2 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (23.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (4.5.0)
# Collecting lightning-utilities>=0.8.0 (from pytorch-lightning)
#   Downloading lightning_utilities-0.9.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (3.8.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lightning) (3.12.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lightning) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lightning) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lightning) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lightning) (2.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (3.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12.0->pytorch-lightning) (2.1.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.12.0->pytorch-lightning) (1.3.0)
# Installing collected packages: lightning-utilities, torchmetrics, pytorch-lightning
# Successfully installed lightning-utilities-0.9.0 pytorch-lightning-2.1.0 torchmetrics-1.2.0

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa
import scipy.signal
import random
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import os
import csv
from sklearn.preprocessing import LabelEncoder
from PIL import Image
import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint

# %%
#!kaggle competitions download -c birdclef-2023
# !unzip birdclef-2023.zip -d /content/dataset
# Out:
# unzip:  cannot find or open birdclef-2023.zip, birdclef-2023.zip.zip or birdclef-2023.zip.ZIP.

# %%
from google.colab import drive
drive.mount('/content/drive')
# !unzip /content/drive/MyDrive/models/birdclef/birdclef-2023.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train_audio/rerswa1/XC330427.ogg
#   inflating: train_audio/rerswa1/XC330925.ogg
#   inflating: train_audio/rerswa1/XC331732.ogg
#   inflating: train_audio/rerswa1/XC333007.ogg
#   inflating: train_audio/rerswa1/XC333008.ogg
#   inflating: train_audio/rerswa1/XC333855.ogg
#   inflating: train_audio/rerswa1/XC334159.ogg
#   inflating: train_audio/rerswa1/XC334160.ogg
#   inflating: train_audio/rerswa1/XC334161.ogg
#   inflating: train_audio/rerswa1/XC370598.ogg
#   inflating: train_audio/rerswa1/XC371021.ogg
#   inflating: train_audio/rerswa1/XC371367.ogg
#   inflating: train_audio/rerswa1/XC376096.ogg
#   inflating: train_audio/rerswa1/XC379520.ogg
#   inflating: train_audio/rerswa1/XC381917.ogg
#   inflating: train_audio/rerswa1/XC382091.ogg
#   inflating: train_audio/rerswa1/XC383377.ogg
#   inflating: train_audio/rerswa1/XC383401.ogg
#   inflating: train_audio/rerswa1/XC384434.ogg
#   inflating: train_audio/rerswa1/XC385379.ogg
#   inflating: train_audio/rerswa1/XC390250.ogg
#   inflating: train_audio/rerswa1/XC390252.ogg
#   inflating: train_audio/rerswa1/XC390253.ogg
#   inflating: train_audio/rerswa1/XC390255.ogg
#   inflating: train_audio/rerswa1/XC390256.ogg
#   inflating: train_audio/rerswa1/XC390257.ogg
#   inflating: train_audio/rerswa1/XC390259.ogg
#   inflating: train_audio/rerswa1/XC390260.ogg
#   inflating: train_audio/rerswa1/XC390262.ogg
#   inflating: train_audio/rerswa1/XC390263.ogg
#   inflating: train_audio/rerswa1/XC390265.ogg
#   inflating: train_audio/rerswa1/XC399234.ogg
#   inflating: train_audio/rerswa1/XC411312.ogg
#   inflating: train_audio/rerswa1/XC417707.ogg
#   inflating: train_audio/rerswa1/XC423136.ogg
#   inflating: train_audio/rerswa1/XC423900.ogg
#   inflating: train_audio/rerswa1/XC423901.ogg
#   inflating: train_audio/rerswa1/XC423902.ogg
#   inflating: train_audio/rerswa1/XC423903.ogg
#   inflating: train_audio/rerswa1/XC423904.ogg
#   inflating: train_audio/rerswa1/XC423906.ogg
#   inflating: train_audio/rerswa1/XC423908.ogg
#   inflating: train_audio/rerswa1/XC423909.ogg
#   inflating: train_audio/rerswa1/XC423911.ogg
#   inflating: train_audio/rerswa1/XC423912.ogg
#   inflating: train_audio/rerswa1/XC423913.ogg
#   inflating: train_audio/rerswa1/XC423972.ogg
#   inflating: train_audio/rerswa1/XC423973.ogg
#   inflating: train_audio/rerswa1/XC423974.ogg
#   inflating: train_audio/rerswa1/XC423975.ogg
#   inflating: train_audio/rerswa1/XC423976.ogg
#   inflating: train_audio/rerswa1/XC423977.ogg
#   inflating: train_audio/rerswa1/XC423978.ogg
#   inflating: train_audio/rerswa1/XC423979.ogg
#   inflating: train_audio/rerswa1/XC423980.ogg
#   inflating: train_audio/rerswa1/XC423981.ogg
#   inflating: train_audio/rerswa1/XC423982.ogg
#   inflating: train_audio/rerswa1/XC423983.ogg
#   inflating: train_audio/rerswa1/XC423984.ogg
#   inflating: train_audio/rerswa1/XC430742.ogg
#   inflating: train_audio/rerswa1/XC432571.ogg
#   inflating: train_audio/rerswa1/XC432573.ogg
#   inflating: train_audio/rerswa1/XC433097.ogg
#   inflating: train_audio/rerswa1/XC433098.ogg
#   inflating: train_audio/rerswa1/XC434073.ogg
#   inflating: train_audio/rerswa1/XC434074.ogg
#   inflating: train_audio/rerswa1/XC436339.ogg
#   inflating: train_audio/rerswa1/XC436340.ogg
#   inflating: train_audio/rerswa1/XC436739.ogg
#   inflating: train_audio/rerswa1/XC437891.ogg
#   inflating: train_audio/rerswa1/XC442768.ogg
#   inflating: train_audio/rerswa1/XC445617.ogg
#   inflating: train_audio/rerswa1/XC445700.ogg
#   inflating: train_audio/rerswa1/XC447361.ogg
#   inflating: train_audio/rerswa1/XC460972.ogg
#   inflating: train_audio/rerswa1/XC463162.ogg
#   inflating: train_audio/rerswa1/XC463164.ogg
#   inflating: train_audio/rerswa1/XC464439.ogg
#   inflating: train_audio/rerswa1/XC464975.ogg
#   inflating: train_audio/rerswa1/XC467757.ogg
#   inflating: train_audio/rerswa1/XC469885.ogg
#   inflating: train_audio/rerswa1/XC471774.ogg
#   inflating: train_audio/rerswa1/XC471955.ogg
#   inflating: train_audio/rerswa1/XC471957.ogg
#   inflating: train_audio/rerswa1/XC471959.ogg
#   inflating: train_audio/rerswa1/XC472354.ogg
#   inflating: train_audio/rerswa1/XC478273.ogg
#   inflating: train_audio/rerswa1/XC479591.ogg
#   inflating: train_audio/rerswa1/XC482315.ogg
#   inflating: train_audio/rerswa1/XC485355.ogg
#   inflating: train_audio/rerswa1/XC489638.ogg
#   inflating: train_audio/rerswa1/XC493838.ogg
#   inflating: train_audio/rerswa1/XC495942.ogg
#   inflating: train_audio/rerswa1/XC495943.ogg
#   inflating: train_audio/rerswa1/XC502701.ogg
#   inflating: train_audio/rerswa1/XC558233.ogg
#   inflating: train_audio/rerswa1/XC585423.ogg
#   inflating: train_audio/rerswa1/XC587199.ogg
#   inflating: train_audio/rerswa1/XC587231.ogg
#   inflating: train_audio/rerswa1/XC587771.ogg
#   inflating: train_audio/rerswa1/XC611239.ogg
#   inflating: train_audio/rerswa1/XC627383.ogg
#   inflating: train_audio/rerswa1/XC637458.ogg
#   inflating: train_audio/rerswa1/XC638732.ogg
#   inflating: train_audio/rerswa1/XC642599.ogg
#   inflating: train_audio/rerswa1/XC672468.ogg
#   inflating: train_audio/rerswa1/XC672469.ogg
#   inflating: train_audio/rerswa1/XC697560.ogg
#   inflating: train_audio/rerswa1/XC697561.ogg
#   inflating: train_audio/rerswa1/XC697562.ogg
#   inflating: train_audio/rerswa1/XC697563.ogg
#   inflating: train_audio/rerswa1/XC697564.ogg
#   inflating: train_audio/rerswa1/XC697566.ogg
#   inflating: train_audio/rerswa1/XC699937.ogg
#   inflating: train_audio/rerswa1/XC699938.ogg
#   inflating: train_audio/rerswa1/XC700182.ogg
#   inflating: train_audio/rerswa1/XC701888.ogg
#   inflating: train_audio/rerswa1/XC701889.ogg
#   inflating: train_audio/rerswa1/XC701890.ogg
#   inflating: train_audio/rerswa1/XC701891.ogg
#   inflating: train_audio/rerswa1/XC701892.ogg
#   inflating: train_audio/rerswa1/XC713333.ogg
#   inflating: train_audio/rerswa1/XC721768.ogg
#   inflating: train_audio/rerswa1/XC722419.ogg
#   inflating: train_audio/rerswa1/XC723730.ogg
#   inflating: train_audio/rerswa1/XC732234.ogg
#   inflating: train_audio/rerswa1/XC734501.ogg
#   inflating: train_audio/rerswa1/XC734720.ogg
#   inflating: train_audio/rerswa1/XC734722.ogg
#   inflating: train_audio/rerswa1/XC735053.ogg
#   inflating: train_audio/rerswa1/XC736964.ogg
#   inflating: train_audio/rerswa1/XC736972.ogg
#   inflating: train_audio/rerswa1/XC740067.ogg
#   inflating: train_audio/rerswa1/XC749418.ogg
#   inflating: train_audio/rerswa1/XC749444.ogg
#   inflating: train_audio/rerswa1/XC753215.ogg
#   inflating: train_audio/rerswa1/XC753896.ogg
#   inflating: train_audio/rerswa1/XC755868.ogg
#   inflating: train_audio/rewsta1/XC195730.ogg
#   inflating: train_audio/rewsta1/XC252685.ogg
#   inflating: train_audio/rewsta1/XC252686.ogg
#   inflating: train_audio/rewsta1/XC253609.ogg
#   inflating: train_audio/rewsta1/XC256479.ogg
#   inflating: train_audio/rewsta1/XC293959.ogg
#   inflating: train_audio/rewsta1/XC316060.ogg
#   inflating: train_audio/rewsta1/XC352943.ogg
#   inflating: train_audio/rewsta1/XC363177.ogg
#   inflating: train_audio/rewsta1/XC366678.ogg
#   inflating: train_audio/rewsta1/XC375310.ogg
#   inflating: train_audio/rewsta1/XC388315.ogg
#   inflating: train_audio/rewsta1/XC391184.ogg
#   inflating: train_audio/rewsta1/XC396246.ogg
#   inflating: train_audio/rewsta1/XC407459.ogg
#   inflating: train_audio/rewsta1/XC408757.ogg
#   inflating: train_audio/rewsta1/XC428628.ogg
#   inflating: train_audio/rewsta1/XC457332.ogg
#   inflating: train_audio/rewsta1/XC459431.ogg
#   inflating: train_audio/rewsta1/XC466842.ogg
#   inflating: train_audio/rewsta1/XC490784.ogg
#   inflating: train_audio/rewsta1/XC56701.ogg
#   inflating: train_audio/rewsta1/XC671164.ogg
#   inflating: train_audio/rewsta1/XC674296.ogg
#   inflating: train_audio/rewsta1/XC695668.ogg
#   inflating: train_audio/rewsta1/XC697908.ogg
#   inflating: train_audio/rewsta1/XC728970.ogg
#   inflating: train_audio/rewsta1/XC750381.ogg
#   inflating: train_audio/rindov/XC125816.ogg
#   inflating: train_audio/rindov/XC126137.ogg
#   inflating: train_audio/rindov/XC126138.ogg
#   inflating: train_audio/rindov/XC126141.ogg
#   inflating: train_audio/rindov/XC126142.ogg
#   inflating: train_audio/rindov/XC126144.ogg
#   inflating: train_audio/rindov/XC126485.ogg
#   inflating: train_audio/rindov/XC126739.ogg
#   inflating: train_audio/rindov/XC126741.ogg
#   inflating: train_audio/rindov/XC163358.ogg
#   inflating: train_audio/rindov/XC166372.ogg
#   inflating: train_audio/rindov/XC168106.ogg
#   inflating: train_audio/rindov/XC168107.ogg
#   inflating: train_audio/rindov/XC173077.ogg
#   inflating: train_audio/rindov/XC195511.ogg
#   inflating: train_audio/rindov/XC195719.ogg
#   inflating: train_audio/rindov/XC195763.ogg
#   inflating: train_audio/rindov/XC201020.ogg
#   inflating: train_audio/rindov/XC206035.ogg
#   inflating: train_audio/rindov/XC206394.ogg
#   inflating: train_audio/rindov/XC207714.ogg
#   inflating: train_audio/rindov/XC208609.ogg
#   inflating: train_audio/rindov/XC213645.ogg
#   inflating: train_audio/rindov/XC218088.ogg
#   inflating: train_audio/rindov/XC233907.ogg
#   inflating: train_audio/rindov/XC239817.ogg
#   inflating: train_audio/rindov/XC240871.ogg
#   inflating: train_audio/rindov/XC252346.ogg
#   inflating: train_audio/rindov/XC252760.ogg
#   inflating: train_audio/rindov/XC252916.ogg
#   inflating: train_audio/rindov/XC267217.ogg
#   inflating: train_audio/rindov/XC292269.ogg
#   inflating: train_audio/rindov/XC308359.ogg
#   inflating: train_audio/rindov/XC309834.ogg
#   inflating: train_audio/rindov/XC319121.ogg
#   inflating: train_audio/rindov/XC324656.ogg
#   inflating: train_audio/rindov/XC326131.ogg
#   inflating: train_audio/rindov/XC326419.ogg
#   inflating: train_audio/rindov/XC344997.ogg
#   inflating: train_audio/rindov/XC363890.ogg
#   inflating: train_audio/rindov/XC364496.ogg
#   inflating: train_audio/rindov/XC364497.ogg
#   inflating: train_audio/rindov/XC368178.ogg
#   inflating: train_audio/rindov/XC381678.ogg
#   inflating: train_audio/rindov/XC381679.ogg
#   inflating: train_audio/rindov/XC382937.ogg
#   inflating: train_audio/rindov/XC39420.ogg
#   inflating: train_audio/rindov/XC411728.ogg
#   inflating: train_audio/rindov/XC418182.ogg
#   inflating: train_audio/rindov/XC419931.ogg
#   inflating: train_audio/rindov/XC424519.ogg
#   inflating: train_audio/rindov/XC438493.ogg
#   inflating: train_audio/rindov/XC439520.ogg
#   inflating: train_audio/rindov/XC456491.ogg
#   inflating: train_audio/rindov/XC460645.ogg
#   inflating: train_audio/rindov/XC473746.ogg
#   inflating: train_audio/rindov/XC476288.ogg
#   inflating: train_audio/rindov/XC492171.ogg
#   inflating: train_audio/rindov/XC494119.ogg
#   inflating: train_audio/rindov/XC503304.ogg
#   inflating: train_audio/rindov/XC505938.ogg
#   inflating: train_audio/rindov/XC508241.ogg
#   inflating: train_audio/rindov/XC514039.ogg
#   inflating: train_audio/rindov/XC514162.ogg
#   inflating: train_audio/rindov/XC518620.ogg
#   inflating: train_audio/rindov/XC518759.ogg
#   inflating: train_audio/rindov/XC520700.ogg
#   inflating: train_audio/rindov/XC522847.ogg
#   inflating: train_audio/rindov/XC527109.ogg
#   inflating: train_audio/rindov/XC528740.ogg
#   inflating: train_audio/rindov/XC533477.ogg
#   inflating: train_audio/rindov/XC537198.ogg
#   inflating: train_audio/rindov/XC539236.ogg
#   inflating: train_audio/rindov/XC542697.ogg
#   inflating: train_audio/rindov/XC546907.ogg
#   inflating: train_audio/rindov/XC549086.ogg
#   inflating: train_audio/rindov/XC559410.ogg
#   inflating: train_audio/rindov/XC571405.ogg
#   inflating: train_audio/rindov/XC571406.ogg
#   inflating: train_audio/rindov/XC583184.ogg
#   inflating: train_audio/rindov/XC583185.ogg
#   inflating: train_audio/rindov/XC584736.ogg
#   inflating: train_audio/rindov/XC585188.ogg
#   inflating: train_audio/rindov/XC586178.ogg
#   inflating: train_audio/rindov/XC586183.ogg
#   inflating: train_audio/rindov/XC594126.ogg
#   inflating: train_audio/rindov/XC605850.ogg
#   inflating: train_audio/rindov/XC613450.ogg
#   inflating: train_audio/rindov/XC613451.ogg
#   inflating: train_audio/rindov/XC613455.ogg
#   inflating: train_audio/rindov/XC615289.ogg
#   inflating: train_audio/rindov/XC621302.ogg
#   inflating: train_audio/rindov/XC621419.ogg
#   inflating: train_audio/rindov/XC621768.ogg
#   inflating: train_audio/rindov/XC622179.ogg
#   inflating: train_audio/rindov/XC622847.ogg
#   inflating: train_audio/rindov/XC622848.ogg
#   inflating: train_audio/rindov/XC622849.ogg
#   inflating: train_audio/rindov/XC637856.ogg
#   inflating: train_audio/rindov/XC638190.ogg
#   inflating: train_audio/rindov/XC647040.ogg
#   inflating: train_audio/rindov/XC650029.ogg
#   inflating: train_audio/rindov/XC654446.ogg
#   inflating: train_audio/rindov/XC655030.ogg
#   inflating: train_audio/rindov/XC658460.ogg
#   inflating: train_audio/rindov/XC659017.ogg
#   inflating: train_audio/rindov/XC664214.ogg
#   inflating: train_audio/rindov/XC664887.ogg
#   inflating: train_audio/rindov/XC671578.ogg
#   inflating: train_audio/rindov/XC680920.ogg
#   inflating: train_audio/rindov/XC682286.ogg
#   inflating: train_audio/rindov/XC683132.ogg
#   inflating: train_audio/rindov/XC717007.ogg
#   inflating: train_audio/rindov/XC746623.ogg
#   inflating: train_audio/rindov/XC750383.ogg
#   inflating: train_audio/rindov/XC753899.ogg
#   inflating: train_audio/rocmar2/XC118188.ogg
#   inflating: train_audio/rocmar2/XC118190.ogg
#   inflating: train_audio/rocmar2/XC322622.ogg
#   inflating: train_audio/rocmar2/XC322625.ogg
#   inflating: train_audio/rocmar2/XC383375.ogg
#   inflating: train_audio/rocmar2/XC383378.ogg
#   inflating: train_audio/rocmar2/XC387149.ogg
#   inflating: train_audio/rocmar2/XC516839.ogg
#   inflating: train_audio/rocmar2/XC516847.ogg
#   inflating: train_audio/rocmar2/XC516851.ogg
#   inflating: train_audio/rocmar2/XC517246.ogg
#   inflating: train_audio/rocmar2/XC517251.ogg
#   inflating: train_audio/rocmar2/XC517361.ogg
#   inflating: train_audio/rocmar2/XC517362.ogg
#   inflating: train_audio/rocmar2/XC517363.ogg
#   inflating: train_audio/rocmar2/XC569580.ogg
#   inflating: train_audio/rocmar2/XC569585.ogg
#   inflating: train_audio/rocmar2/XC569590.ogg
#   inflating: train_audio/rocmar2/XC569608.ogg
#   inflating: train_audio/rocmar2/XC569615.ogg
#   inflating: train_audio/rocmar2/XC689713.ogg
#   inflating: train_audio/rocmar2/XC735229.ogg
#   inflating: train_audio/rostur1/XC282066.ogg
#   inflating: train_audio/rostur1/XC289531.ogg
#   inflating: train_audio/rostur1/XC289532.ogg
#   inflating: train_audio/rostur1/XC365419.ogg
#   inflating: train_audio/rostur1/XC393727.ogg
#   inflating: train_audio/rostur1/XC396133.ogg
#   inflating: train_audio/rostur1/XC397201.ogg
#   inflating: train_audio/rostur1/XC401762.ogg
#   inflating: train_audio/rostur1/XC417117.ogg
#   inflating: train_audio/rostur1/XC537043.ogg
#   inflating: train_audio/ruegls1/XC117140.ogg
#   inflating: train_audio/ruegls1/XC117142.ogg
#   inflating: train_audio/ruegls1/XC131311.ogg
#   inflating: train_audio/ruegls1/XC131661.ogg
#   inflating: train_audio/ruegls1/XC138678.ogg
#   inflating: train_audio/ruegls1/XC138679.ogg
#   inflating: train_audio/ruegls1/XC210336.ogg
#   inflating: train_audio/ruegls1/XC210337.ogg
#   inflating: train_audio/ruegls1/XC237761.ogg
#   inflating: train_audio/ruegls1/XC237763.ogg
#   inflating: train_audio/ruegls1/XC237765.ogg
#   inflating: train_audio/ruegls1/XC247898.ogg
#   inflating: train_audio/ruegls1/XC252342.ogg
#   inflating: train_audio/ruegls1/XC281992.ogg
#   inflating: train_audio/ruegls1/XC282020.ogg
#   inflating: train_audio/ruegls1/XC285544.ogg
#   inflating: train_audio/ruegls1/XC293978.ogg
#   inflating: train_audio/ruegls1/XC294696.ogg
#   inflating: train_audio/ruegls1/XC364252.ogg
#   inflating: train_audio/ruegls1/XC396427.ogg
#   inflating: train_audio/ruegls1/XC398382.ogg
#   inflating: train_audio/ruegls1/XC410588.ogg
#   inflating: train_audio/ruegls1/XC444351.ogg
#   inflating: train_audio/ruegls1/XC444915.ogg
#   inflating: train_audio/ruegls1/XC537113.ogg
#   inflating: train_audio/ruegls1/XC608033.ogg
#   inflating: train_audio/ruegls1/XC616589.ogg
#   inflating: train_audio/ruegls1/XC616594.ogg
#   inflating: train_audio/ruegls1/XC701339.ogg
#   inflating: train_audio/ruegls1/XC701668.ogg
#   inflating: train_audio/ruegls1/XC701859.ogg
#   inflating: train_audio/ruegls1/XC748259.ogg
#   inflating: train_audio/ruegls1/XC748260.ogg
#   inflating: train_audio/rufcha2/XC209977.ogg
#   inflating: train_audio/rufcha2/XC209978.ogg
#   inflating: train_audio/rufcha2/XC209979.ogg
#   inflating: train_audio/rufcha2/XC294730.ogg
#   inflating: train_audio/rufcha2/XC396571.ogg
#   inflating: train_audio/rufcha2/XC467105.ogg
#   inflating: train_audio/sacibi2/XC252633.ogg
#   inflating: train_audio/sacibi2/XC309388.ogg
#   inflating: train_audio/sacibi2/XC417635.ogg
#   inflating: train_audio/sacibi2/XC505935.ogg
#   inflating: train_audio/sacibi2/XC652185.ogg
#   inflating: train_audio/sacibi2/XC661232.ogg
#   inflating: train_audio/sccsun2/XC137077.ogg
#   inflating: train_audio/sccsun2/XC137078.ogg
#   inflating: train_audio/sccsun2/XC157093.ogg
#   inflating: train_audio/sccsun2/XC158287.ogg
#   inflating: train_audio/sccsun2/XC170277.ogg
#   inflating: train_audio/sccsun2/XC195026.ogg
#   inflating: train_audio/sccsun2/XC195027.ogg
#   inflating: train_audio/sccsun2/XC195521.ogg
#   inflating: train_audio/sccsun2/XC195527.ogg
#   inflating: train_audio/sccsun2/XC201170.ogg
#   inflating: train_audio/sccsun2/XC253603.ogg
#   inflating: train_audio/sccsun2/XC298959.ogg
#   inflating: train_audio/sccsun2/XC309478.ogg
#   inflating: train_audio/sccsun2/XC326171.ogg
#   inflating: train_audio/sccsun2/XC332254.ogg
#   inflating: train_audio/sccsun2/XC349559.ogg
#   inflating: train_audio/sccsun2/XC363886.ogg
#   inflating: train_audio/sccsun2/XC375040.ogg
#   inflating: train_audio/sccsun2/XC380521.ogg
#   inflating: train_audio/sccsun2/XC382967.ogg
#   inflating: train_audio/sccsun2/XC386002.ogg
#   inflating: train_audio/sccsun2/XC391989.ogg
#   inflating: train_audio/sccsun2/XC392049.ogg
#   inflating: train_audio/sccsun2/XC393628.ogg
#   inflating: train_audio/sccsun2/XC394500.ogg
#   inflating: train_audio/sccsun2/XC398563.ogg
#   inflating: train_audio/sccsun2/XC398625.ogg
#   inflating: train_audio/sccsun2/XC402522.ogg
#   inflating: train_audio/sccsun2/XC404434.ogg
#   inflating: train_audio/sccsun2/XC419930.ogg
#   inflating: train_audio/sccsun2/XC419932.ogg
#   inflating: train_audio/sccsun2/XC437897.ogg
#   inflating: train_audio/sccsun2/XC439791.ogg
#   inflating: train_audio/sccsun2/XC453997.ogg
#   inflating: train_audio/sccsun2/XC471330.ogg
#   inflating: train_audio/sccsun2/XC523613.ogg
#   inflating: train_audio/sccsun2/XC525936.ogg
#   inflating: train_audio/sccsun2/XC536795.ogg
#   inflating: train_audio/sccsun2/XC537108.ogg
#   inflating: train_audio/sccsun2/XC537125.ogg
#   inflating: train_audio/sccsun2/XC545260.ogg
#   inflating: train_audio/sccsun2/XC564159.ogg
#   inflating: train_audio/sccsun2/XC581949.ogg
#   inflating: train_audio/sccsun2/XC593225.ogg
#   inflating: train_audio/sccsun2/XC593227.ogg
#   inflating: train_audio/sccsun2/XC598039.ogg
#   inflating: train_audio/sccsun2/XC598040.ogg
#   inflating: train_audio/sccsun2/XC600158.ogg
#   inflating: train_audio/sccsun2/XC600159.ogg
#   inflating: train_audio/sccsun2/XC608050.ogg
#   inflating: train_audio/sccsun2/XC609125.ogg
#   inflating: train_audio/sccsun2/XC609126.ogg
#   inflating: train_audio/sccsun2/XC609128.ogg
#   inflating: train_audio/sccsun2/XC609472.ogg
#   inflating: train_audio/sccsun2/XC609477.ogg
#   inflating: train_audio/sccsun2/XC609478.ogg
#   inflating: train_audio/sccsun2/XC609479.ogg
#   inflating: train_audio/sccsun2/XC619392.ogg
#   inflating: train_audio/sccsun2/XC620842.ogg
#   inflating: train_audio/sccsun2/XC620843.ogg
#   inflating: train_audio/sccsun2/XC627224.ogg
#   inflating: train_audio/sccsun2/XC627670.ogg
#   inflating: train_audio/sccsun2/XC633698.ogg
#   inflating: train_audio/sccsun2/XC633824.ogg
#   inflating: train_audio/sccsun2/XC633825.ogg
#   inflating: train_audio/sccsun2/XC634128.ogg
#   inflating: train_audio/sccsun2/XC634131.ogg
#   inflating: train_audio/sccsun2/XC645219.ogg
#   inflating: train_audio/sccsun2/XC650845.ogg
#   inflating: train_audio/sccsun2/XC652450.ogg
#   inflating: train_audio/sccsun2/XC681392.ogg
#   inflating: train_audio/sccsun2/XC683976.ogg
#   inflating: train_audio/sccsun2/XC683977.ogg
#   inflating: train_audio/sccsun2/XC697933.ogg
#   inflating: train_audio/sccsun2/XC703041.ogg
#   inflating: train_audio/sccsun2/XC747949.ogg
#   inflating: train_audio/sccsun2/XC752954.ogg
#   inflating: train_audio/sccsun2/XC753434.ogg
#   inflating: train_audio/scrcha1/XC138684.ogg
#   inflating: train_audio/scrcha1/XC155166.ogg
#   inflating: train_audio/scrcha1/XC158716.ogg
#   inflating: train_audio/scrcha1/XC17981.ogg
#   inflating: train_audio/scrcha1/XC17982.ogg
#   inflating: train_audio/scrcha1/XC17983.ogg
#   inflating: train_audio/scrcha1/XC17984.ogg
#   inflating: train_audio/scrcha1/XC208572.ogg
#   inflating: train_audio/scrcha1/XC302346.ogg
#   inflating: train_audio/scrcha1/XC310035.ogg
#   inflating: train_audio/scrcha1/XC34016.ogg
#   inflating: train_audio/scrcha1/XC355740.ogg
#   inflating: train_audio/scrcha1/XC360325.ogg
#   inflating: train_audio/scrcha1/XC371364.ogg
#   inflating: train_audio/scrcha1/XC400413.ogg
#   inflating: train_audio/scrcha1/XC403251.ogg
#   inflating: train_audio/scrcha1/XC404166.ogg
#   inflating: train_audio/scrcha1/XC46225.ogg
#   inflating: train_audio/scrcha1/XC477668.ogg
#   inflating: train_audio/scrcha1/XC482894.ogg
#   inflating: train_audio/scrcha1/XC529159.ogg
#   inflating: train_audio/scrcha1/XC530136.ogg
#   inflating: train_audio/scrcha1/XC530137.ogg
#   inflating: train_audio/scrcha1/XC530138.ogg
#   inflating: train_audio/scrcha1/XC530139.ogg
#   inflating: train_audio/scrcha1/XC530140.ogg
#   inflating: train_audio/scrcha1/XC530154.ogg
#   inflating: train_audio/scrcha1/XC700641.ogg
#   inflating: train_audio/scrcha1/XC700642.ogg
#   inflating: train_audio/scrcha1/XC756743.ogg
#   inflating: train_audio/scthon1/XC125616.ogg
#   inflating: train_audio/scthon1/XC125617.ogg
#   inflating: train_audio/scthon1/XC158044.ogg
#   inflating: train_audio/scthon1/XC200766.ogg
#   inflating: train_audio/scthon1/XC200767.ogg
#   inflating: train_audio/scthon1/XC254867.ogg
#   inflating: train_audio/scthon1/XC265786.ogg
#   inflating: train_audio/scthon1/XC266088.ogg
#   inflating: train_audio/scthon1/XC294934.ogg
#   inflating: train_audio/scthon1/XC316932.ogg
#   inflating: train_audio/scthon1/XC323373.ogg
#   inflating: train_audio/scthon1/XC342108.ogg
#   inflating: train_audio/scthon1/XC429223.ogg
#   inflating: train_audio/scthon1/XC429457.ogg
#   inflating: train_audio/scthon1/XC441621.ogg
#   inflating: train_audio/scthon1/XC442066.ogg
#   inflating: train_audio/scthon1/XC453330.ogg
#   inflating: train_audio/scthon1/XC460518.ogg
#   inflating: train_audio/scthon1/XC460519.ogg
#   inflating: train_audio/scthon1/XC492729.ogg
#   inflating: train_audio/scthon1/XC532751.ogg
#   inflating: train_audio/scthon1/XC532752.ogg
#   inflating: train_audio/scthon1/XC536485.ogg
#   inflating: train_audio/scthon1/XC682338.ogg
#   inflating: train_audio/scthon1/XC725218.ogg
#   inflating: train_audio/shesta1/XC209997.ogg
#   inflating: train_audio/shesta1/XC209999.ogg
#   inflating: train_audio/shesta1/XC294379.ogg
#   inflating: train_audio/sichor1/XC127935.ogg
#   inflating: train_audio/sichor1/XC216058.ogg
#   inflating: train_audio/sichor1/XC216059.ogg
#   inflating: train_audio/sichor1/XC216060.ogg
#   inflating: train_audio/sichor1/XC294403.ogg
#   inflating: train_audio/sichor1/XC294947.ogg
#   inflating: train_audio/sichor1/XC372269.ogg
#   inflating: train_audio/sichor1/XC372271.ogg
#   inflating: train_audio/sichor1/XC394077.ogg
#   inflating: train_audio/sichor1/XC394078.ogg
#   inflating: train_audio/sichor1/XC410295.ogg
#   inflating: train_audio/sichor1/XC426284.ogg
#   inflating: train_audio/sichor1/XC426325.ogg
#   inflating: train_audio/sichor1/XC446022.ogg
#   inflating: train_audio/sichor1/XC446023.ogg
#   inflating: train_audio/sichor1/XC446028.ogg
#   inflating: train_audio/sichor1/XC446029.ogg
#   inflating: train_audio/sichor1/XC452423.ogg
#   inflating: train_audio/sichor1/XC452453.ogg
#   inflating: train_audio/sichor1/XC452651.ogg
#   inflating: train_audio/sichor1/XC467349.ogg
#   inflating: train_audio/sichor1/XC474159.ogg
#   inflating: train_audio/sichor1/XC474160.ogg
#   inflating: train_audio/sichor1/XC514511.ogg
#   inflating: train_audio/sichor1/XC514561.ogg
#   inflating: train_audio/sichor1/XC514639.ogg
#   inflating: train_audio/sichor1/XC514883.ogg
#   inflating: train_audio/sichor1/XC514972.ogg
#   inflating: train_audio/sichor1/XC515205.ogg
#   inflating: train_audio/sichor1/XC515240.ogg
#   inflating: train_audio/sichor1/XC515678.ogg
#   inflating: train_audio/sichor1/XC516515.ogg
#   inflating: train_audio/sichor1/XC516526.ogg
#   inflating: train_audio/sichor1/XC516590.ogg
#   inflating: train_audio/sichor1/XC516592.ogg
#   inflating: train_audio/sichor1/XC517154.ogg
#   inflating: train_audio/sichor1/XC517162.ogg
#   inflating: train_audio/sichor1/XC517342.ogg
#   inflating: train_audio/sichor1/XC517352.ogg
#   inflating: train_audio/sichor1/XC581908.ogg
#   inflating: train_audio/sichor1/XC610569.ogg
#   inflating: train_audio/sichor1/XC697672.ogg
#   inflating: train_audio/sichor1/XC701734.ogg
#   inflating: train_audio/sichor1/XC755403.ogg
#   inflating: train_audio/sichor1/XC755843.ogg
#   inflating: train_audio/sincis1/XC120616.ogg
#   inflating: train_audio/sincis1/XC132729.ogg
#   inflating: train_audio/sincis1/XC195774.ogg
#   inflating: train_audio/sincis1/XC246366.ogg
#   inflating: train_audio/sincis1/XC283721.ogg
#   inflating: train_audio/sincis1/XC283722.ogg
#   inflating: train_audio/sincis1/XC294335.ogg
#   inflating: train_audio/sincis1/XC294637.ogg
#   inflating: train_audio/sincis1/XC298916.ogg
#   inflating: train_audio/sincis1/XC298917.ogg
#   inflating: train_audio/sincis1/XC299125.ogg
#   inflating: train_audio/sincis1/XC301367.ogg
#   inflating: train_audio/sincis1/XC301462.ogg
#   inflating: train_audio/sincis1/XC311034.ogg
#   inflating: train_audio/sincis1/XC352772.ogg
#   inflating: train_audio/sincis1/XC352773.ogg
#   inflating: train_audio/sincis1/XC366835.ogg
#   inflating: train_audio/sincis1/XC370450.ogg
#   inflating: train_audio/sincis1/XC370451.ogg
#   inflating: train_audio/sincis1/XC375101.ogg
#   inflating: train_audio/sincis1/XC375102.ogg
#   inflating: train_audio/sincis1/XC376196.ogg
#   inflating: train_audio/sincis1/XC376198.ogg
#   inflating: train_audio/sincis1/XC376491.ogg
#   inflating: train_audio/sincis1/XC400466.ogg
#   inflating: train_audio/sincis1/XC402460.ogg
#   inflating: train_audio/sincis1/XC402461.ogg
#   inflating: train_audio/sincis1/XC405706.ogg
#   inflating: train_audio/sincis1/XC432647.ogg
#   inflating: train_audio/sincis1/XC432648.ogg
#   inflating: train_audio/sincis1/XC432649.ogg
#   inflating: train_audio/sincis1/XC440462.ogg
#   inflating: train_audio/sincis1/XC446113.ogg
#   inflating: train_audio/sincis1/XC446259.ogg
#   inflating: train_audio/sincis1/XC452934.ogg
#   inflating: train_audio/sincis1/XC46224.ogg
#   inflating: train_audio/sincis1/XC474299.ogg
#   inflating: train_audio/sincis1/XC474466.ogg
#   inflating: train_audio/sincis1/XC474467.ogg
#   inflating: train_audio/sincis1/XC481715.ogg
#   inflating: train_audio/sincis1/XC481716.ogg
#   inflating: train_audio/sincis1/XC481717.ogg
#   inflating: train_audio/sincis1/XC518392.ogg
#   inflating: train_audio/sincis1/XC523505.ogg
#   inflating: train_audio/sincis1/XC537453.ogg
#   inflating: train_audio/sincis1/XC537544.ogg
#   inflating: train_audio/sincis1/XC541102.ogg
#   inflating: train_audio/sincis1/XC562039.ogg
#   inflating: train_audio/sincis1/XC578860.ogg
#   inflating: train_audio/sincis1/XC57980.ogg
#   inflating: train_audio/sincis1/XC590111.ogg
#   inflating: train_audio/sincis1/XC611512.ogg
#   inflating: train_audio/sincis1/XC612842.ogg
#   inflating: train_audio/sincis1/XC619564.ogg
#   inflating: train_audio/sincis1/XC620840.ogg
#   inflating: train_audio/sincis1/XC620841.ogg
#   inflating: train_audio/sincis1/XC622852.ogg
#   inflating: train_audio/sincis1/XC624668.ogg
#   inflating: train_audio/sincis1/XC624669.ogg
#   inflating: train_audio/sincis1/XC627231.ogg
#   inflating: train_audio/sincis1/XC627234.ogg
#   inflating: train_audio/sincis1/XC627667.ogg
#   inflating: train_audio/sincis1/XC645218.ogg
#   inflating: train_audio/sincis1/XC647616.ogg
#   inflating: train_audio/sincis1/XC675464.ogg
#   inflating: train_audio/sincis1/XC736018.ogg
#   inflating: train_audio/sincis1/XC755418.ogg
#   inflating: train_audio/sincis1/XC756786.ogg
#   inflating: train_audio/slbgre1/XC137901.ogg
#   inflating: train_audio/slbgre1/XC207918.ogg
#   inflating: train_audio/slbgre1/XC207938.ogg
#   inflating: train_audio/slbgre1/XC208652.ogg
#   inflating: train_audio/slbgre1/XC237130.ogg
#   inflating: train_audio/slbgre1/XC240499.ogg
#   inflating: train_audio/slbgre1/XC262790.ogg
#   inflating: train_audio/slbgre1/XC262795.ogg
#   inflating: train_audio/slbgre1/XC263202.ogg
#   inflating: train_audio/slbgre1/XC263464.ogg
#   inflating: train_audio/slbgre1/XC284897.ogg
#   inflating: train_audio/slbgre1/XC285168.ogg
#   inflating: train_audio/slbgre1/XC291320.ogg
#   inflating: train_audio/slbgre1/XC301228.ogg
#   inflating: train_audio/slbgre1/XC315869.ogg
#   inflating: train_audio/slbgre1/XC344138.ogg
#   inflating: train_audio/slbgre1/XC360416.ogg
#   inflating: train_audio/slbgre1/XC364367.ogg
#   inflating: train_audio/slbgre1/XC388660.ogg
#   inflating: train_audio/slbgre1/XC401824.ogg
#   inflating: train_audio/slbgre1/XC418604.ogg
#   inflating: train_audio/slbgre1/XC508455.ogg
#   inflating: train_audio/slbgre1/XC704576.ogg
#   inflating: train_audio/slcbou1/XC128198.ogg
#   inflating: train_audio/slcbou1/XC173035.ogg
#   inflating: train_audio/slcbou1/XC178858.ogg
#   inflating: train_audio/slcbou1/XC200022.ogg
#   inflating: train_audio/slcbou1/XC200024.ogg
#   inflating: train_audio/slcbou1/XC201374.ogg
#   inflating: train_audio/slcbou1/XC234379.ogg
#   inflating: train_audio/slcbou1/XC234380.ogg
#   inflating: train_audio/slcbou1/XC237766.ogg
#   inflating: train_audio/slcbou1/XC267195.ogg
#   inflating: train_audio/slcbou1/XC267200.ogg
#   inflating: train_audio/slcbou1/XC294698.ogg
#   inflating: train_audio/slcbou1/XC294886.ogg
#   inflating: train_audio/slcbou1/XC344498.ogg
#   inflating: train_audio/slcbou1/XC373825.ogg
#   inflating: train_audio/slcbou1/XC373827.ogg
#   inflating: train_audio/slcbou1/XC373829.ogg
#   inflating: train_audio/slcbou1/XC396569.ogg
#   inflating: train_audio/slcbou1/XC397694.ogg
#   inflating: train_audio/slcbou1/XC399473.ogg
#   inflating: train_audio/slcbou1/XC425333.ogg
#   inflating: train_audio/slcbou1/XC432643.ogg
#   inflating: train_audio/slcbou1/XC432644.ogg
#   inflating: train_audio/slcbou1/XC440040.ogg
#   inflating: train_audio/slcbou1/XC440823.ogg
#   inflating: train_audio/slcbou1/XC444526.ogg
#   inflating: train_audio/slcbou1/XC445057.ogg
#   inflating: train_audio/slcbou1/XC445058.ogg
#   inflating: train_audio/slcbou1/XC457572.ogg
#   inflating: train_audio/slcbou1/XC460484.ogg
#   inflating: train_audio/slcbou1/XC460639.ogg
#   inflating: train_audio/slcbou1/XC460641.ogg
#   inflating: train_audio/slcbou1/XC473965.ogg
#   inflating: train_audio/slcbou1/XC477669.ogg
#   inflating: train_audio/slcbou1/XC583160.ogg
#   inflating: train_audio/slcbou1/XC583178.ogg
#   inflating: train_audio/slcbou1/XC587621.ogg
#   inflating: train_audio/slcbou1/XC587622.ogg
#   inflating: train_audio/slcbou1/XC594015.ogg
#   inflating: train_audio/slcbou1/XC601103.ogg
#   inflating: train_audio/slcbou1/XC601799.ogg
#   inflating: train_audio/slcbou1/XC602922.ogg
#   inflating: train_audio/slcbou1/XC603760.ogg
#   inflating: train_audio/slcbou1/XC606275.ogg
#   inflating: train_audio/slcbou1/XC610324.ogg
#   inflating: train_audio/slcbou1/XC613483.ogg
#   inflating: train_audio/slcbou1/XC615014.ogg
#   inflating: train_audio/slcbou1/XC619383.ogg
#   inflating: train_audio/slcbou1/XC753981.ogg
#   inflating: train_audio/slcbou1/XC756908.ogg
#   inflating: train_audio/slcbou1/XC756909.ogg
#   inflating: train_audio/sltnig1/XC129684.ogg
#   inflating: train_audio/sltnig1/XC267444.ogg
#   inflating: train_audio/sltnig1/XC294655.ogg
#   inflating: train_audio/sltnig1/XC294734.ogg
#   inflating: train_audio/sltnig1/XC311717.ogg
#   inflating: train_audio/sltnig1/XC346219.ogg
#   inflating: train_audio/sltnig1/XC390809.ogg
#   inflating: train_audio/sltnig1/XC390812.ogg
#   inflating: train_audio/sltnig1/XC390813.ogg
#   inflating: train_audio/sltnig1/XC390815.ogg
#   inflating: train_audio/sltnig1/XC396101.ogg
#   inflating: train_audio/sltnig1/XC396119.ogg
#   inflating: train_audio/sltnig1/XC398463.ogg
#   inflating: train_audio/sltnig1/XC424342.ogg
#   inflating: train_audio/sltnig1/XC436061.ogg
#   inflating: train_audio/sltnig1/XC436062.ogg
#   inflating: train_audio/sltnig1/XC436063.ogg
#   inflating: train_audio/sltnig1/XC536881.ogg
#   inflating: train_audio/sltnig1/XC577165.ogg
#   inflating: train_audio/sltnig1/XC577166.ogg
#   inflating: train_audio/sltnig1/XC593154.ogg
#   inflating: train_audio/sltnig1/XC593155.ogg
#   inflating: train_audio/sltnig1/XC593156.ogg
#   inflating: train_audio/sltnig1/XC593157.ogg
#   inflating: train_audio/sltnig1/XC624174.ogg
#   inflating: train_audio/sltnig1/XC624177.ogg
#   inflating: train_audio/sltnig1/XC630285.ogg
#   inflating: train_audio/sltnig1/XC630899.ogg
#   inflating: train_audio/sltnig1/XC635369.ogg
#   inflating: train_audio/sltnig1/XC635370.ogg
#   inflating: train_audio/sltnig1/XC669000.ogg
#   inflating: train_audio/sltnig1/XC754004.ogg
#   inflating: train_audio/sltnig1/XC754007.ogg
#   inflating: train_audio/sobfly1/XC153503.ogg
#   inflating: train_audio/sobfly1/XC190166.ogg
#   inflating: train_audio/sobfly1/XC307193.ogg
#   inflating: train_audio/sobfly1/XC307194.ogg
#   inflating: train_audio/sobfly1/XC332369.ogg
#   inflating: train_audio/sobfly1/XC337549.ogg
#   inflating: train_audio/sobfly1/XC359287.ogg
#   inflating: train_audio/sobfly1/XC377000.ogg
#   inflating: train_audio/sobfly1/XC377186.ogg
#   inflating: train_audio/sobfly1/XC377190.ogg
#   inflating: train_audio/sobfly1/XC411726.ogg
#   inflating: train_audio/sobfly1/XC463806.ogg
#   inflating: train_audio/sobfly1/XC552082.ogg
#   inflating: train_audio/sobfly1/XC577167.ogg
#   inflating: train_audio/sobfly1/XC577168.ogg
#   inflating: train_audio/sobfly1/XC577169.ogg
#   inflating: train_audio/sobfly1/XC588370.ogg
#   inflating: train_audio/sobfly1/XC592906.ogg
#   inflating: train_audio/sobfly1/XC674720.ogg
#   inflating: train_audio/sobfly1/XC728751.ogg
#   inflating: train_audio/sobfly1/XC748265.ogg
#   inflating: train_audio/somgre1/XC117155.ogg
#   inflating: train_audio/somgre1/XC118217.ogg
#   inflating: train_audio/somgre1/XC118449.ogg
#   inflating: train_audio/somgre1/XC120252.ogg
#   inflating: train_audio/somgre1/XC120253.ogg
#   inflating: train_audio/somgre1/XC120612.ogg
#   inflating: train_audio/somgre1/XC126513.ogg
#   inflating: train_audio/somgre1/XC126514.ogg
#   inflating: train_audio/somgre1/XC126515.ogg
#   inflating: train_audio/somgre1/XC126530.ogg
#   inflating: train_audio/somgre1/XC126531.ogg
#   inflating: train_audio/somgre1/XC132732.ogg
#   inflating: train_audio/somgre1/XC146483.ogg
#   inflating: train_audio/somgre1/XC154316.ogg
#   inflating: train_audio/somgre1/XC154317.ogg
#   inflating: train_audio/somgre1/XC188927.ogg
#   inflating: train_audio/somgre1/XC193676.ogg
#   inflating: train_audio/somgre1/XC193677.ogg
#   inflating: train_audio/somgre1/XC193678.ogg
#   inflating: train_audio/somgre1/XC194277.ogg
#   inflating: train_audio/somgre1/XC195219.ogg
#   inflating: train_audio/somgre1/XC195220.ogg
#   inflating: train_audio/somgre1/XC195717.ogg
#   inflating: train_audio/somgre1/XC201449.ogg
#   inflating: train_audio/somgre1/XC202635.ogg
#   inflating: train_audio/somgre1/XC202644.ogg
#   inflating: train_audio/somgre1/XC205862.ogg
#   inflating: train_audio/somgre1/XC205863.ogg
#   inflating: train_audio/somgre1/XC216433.ogg
#   inflating: train_audio/somgre1/XC252365.ogg
#   inflating: train_audio/somgre1/XC252585.ogg
#   inflating: train_audio/somgre1/XC252789.ogg
#   inflating: train_audio/somgre1/XC253154.ogg
#   inflating: train_audio/somgre1/XC263489.ogg
#   inflating: train_audio/somgre1/XC265785.ogg
#   inflating: train_audio/somgre1/XC28669.ogg
#   inflating: train_audio/somgre1/XC288878.ogg
#   inflating: train_audio/somgre1/XC292284.ogg
#   inflating: train_audio/somgre1/XC305315.ogg
#   inflating: train_audio/somgre1/XC313300.ogg
#   inflating: train_audio/somgre1/XC313301.ogg
#   inflating: train_audio/somgre1/XC320617.ogg
#   inflating: train_audio/somgre1/XC320618.ogg
#   inflating: train_audio/somgre1/XC320621.ogg
#   inflating: train_audio/somgre1/XC320832.ogg
#   inflating: train_audio/somgre1/XC323368.ogg
#   inflating: train_audio/somgre1/XC332318.ogg
#   inflating: train_audio/somgre1/XC342523.ogg
#   inflating: train_audio/somgre1/XC349566.ogg
#   inflating: train_audio/somgre1/XC353865.ogg
#   inflating: train_audio/somgre1/XC358343.ogg
#   inflating: train_audio/somgre1/XC368175.ogg
#   inflating: train_audio/somgre1/XC369824.ogg
#   inflating: train_audio/somgre1/XC377508.ogg
#   inflating: train_audio/somgre1/XC378612.ogg
#   inflating: train_audio/somgre1/XC382947.ogg
#   inflating: train_audio/somgre1/XC383333.ogg
#   inflating: train_audio/somgre1/XC383334.ogg
#   inflating: train_audio/somgre1/XC383335.ogg
#   inflating: train_audio/somgre1/XC383336.ogg
#   inflating: train_audio/somgre1/XC383337.ogg
#   inflating: train_audio/somgre1/XC383338.ogg
#   inflating: train_audio/somgre1/XC387466.ogg
#   inflating: train_audio/somgre1/XC387467.ogg
#   inflating: train_audio/somgre1/XC390686.ogg
#   inflating: train_audio/somgre1/XC392008.ogg
#   inflating: train_audio/somgre1/XC392022.ogg
#   inflating: train_audio/somgre1/XC405116.ogg
#   inflating: train_audio/somgre1/XC411731.ogg
#   inflating: train_audio/somgre1/XC412148.ogg
#   inflating: train_audio/somgre1/XC412149.ogg
#   inflating: train_audio/somgre1/XC412150.ogg
#   inflating: train_audio/somgre1/XC412151.ogg
#   inflating: train_audio/somgre1/XC412153.ogg
#   inflating: train_audio/somgre1/XC412170.ogg
#   inflating: train_audio/somgre1/XC412174.ogg
#   inflating: train_audio/somgre1/XC412175.ogg
#   inflating: train_audio/somgre1/XC412176.ogg
#   inflating: train_audio/somgre1/XC418500.ogg
#   inflating: train_audio/somgre1/XC418503.ogg
#   inflating: train_audio/somgre1/XC418504.ogg
#   inflating: train_audio/somgre1/XC429387.ogg
#   inflating: train_audio/somgre1/XC429388.ogg
#   inflating: train_audio/somgre1/XC430006.ogg
#   inflating: train_audio/somgre1/XC436073.ogg
#   inflating: train_audio/somgre1/XC438679.ogg
#   inflating: train_audio/somgre1/XC440351.ogg
#   inflating: train_audio/somgre1/XC440353.ogg
#   inflating: train_audio/somgre1/XC442436.ogg
#   inflating: train_audio/somgre1/XC443071.ogg
#   inflating: train_audio/somgre1/XC443072.ogg
#   inflating: train_audio/somgre1/XC443073.ogg
#   inflating: train_audio/somgre1/XC443075.ogg
#   inflating: train_audio/somgre1/XC443076.ogg
#   inflating: train_audio/somgre1/XC443077.ogg
#   inflating: train_audio/somgre1/XC443103.ogg
#   inflating: train_audio/somgre1/XC443510.ogg
#   inflating: train_audio/somgre1/XC443511.ogg
#   inflating: train_audio/somgre1/XC443512.ogg
#   inflating: train_audio/somgre1/XC443513.ogg
#   inflating: train_audio/somgre1/XC443514.ogg
#   inflating: train_audio/somgre1/XC443516.ogg
#   inflating: train_audio/somgre1/XC443517.ogg
#   inflating: train_audio/somgre1/XC443519.ogg
#   inflating: train_audio/somgre1/XC443520.ogg
#   inflating: train_audio/somgre1/XC443521.ogg
#   inflating: train_audio/somgre1/XC443523.ogg
#   inflating: train_audio/somgre1/XC443526.ogg
#   inflating: train_audio/somgre1/XC443747.ogg
#   inflating: train_audio/somgre1/XC444085.ogg
#   inflating: train_audio/somgre1/XC446893.ogg
#   inflating: train_audio/somgre1/XC446894.ogg
#   inflating: train_audio/somgre1/XC452456.ogg
#   inflating: train_audio/somgre1/XC452690.ogg
#   inflating: train_audio/somgre1/XC453659.ogg
#   inflating: train_audio/somgre1/XC459326.ogg
#   inflating: train_audio/somgre1/XC459432.ogg
#   inflating: train_audio/somgre1/XC459433.ogg
#   inflating: train_audio/somgre1/XC459516.ogg
#   inflating: train_audio/somgre1/XC459529.ogg
#   inflating: train_audio/somgre1/XC460509.ogg
#   inflating: train_audio/somgre1/XC463799.ogg
#   inflating: train_audio/somgre1/XC476125.ogg
#   inflating: train_audio/somgre1/XC500534.ogg
#   inflating: train_audio/somgre1/XC505572.ogg
#   inflating: train_audio/somgre1/XC512295.ogg
#   inflating: train_audio/somgre1/XC521829.ogg
#   inflating: train_audio/somgre1/XC524800.ogg
#   inflating: train_audio/somgre1/XC532290.ogg
#   inflating: train_audio/somgre1/XC55765.ogg
#   inflating: train_audio/somgre1/XC563927.ogg
#   inflating: train_audio/somgre1/XC587008.ogg
#   inflating: train_audio/somgre1/XC595796.ogg
#   inflating: train_audio/somgre1/XC600782.ogg
#   inflating: train_audio/somgre1/XC601133.ogg
#   inflating: train_audio/somgre1/XC604510.ogg
#   inflating: train_audio/somgre1/XC606255.ogg
#   inflating: train_audio/somgre1/XC607221.ogg
#   inflating: train_audio/somgre1/XC607222.ogg
#   inflating: train_audio/somgre1/XC607223.ogg
#   inflating: train_audio/somgre1/XC608053.ogg
#   inflating: train_audio/somgre1/XC608054.ogg
#   inflating: train_audio/somgre1/XC609998.ogg
#   inflating: train_audio/somgre1/XC609999.ogg
#   inflating: train_audio/somgre1/XC622666.ogg
#   inflating: train_audio/somgre1/XC625687.ogg
#   inflating: train_audio/somgre1/XC626173.ogg
#   inflating: train_audio/somgre1/XC629399.ogg
#   inflating: train_audio/somgre1/XC632111.ogg
#   inflating: train_audio/somgre1/XC633695.ogg
#   inflating: train_audio/somgre1/XC633696.ogg
#   inflating: train_audio/somgre1/XC633717.ogg
#   inflating: train_audio/somgre1/XC633723.ogg
#   inflating: train_audio/somgre1/XC633750.ogg
#   inflating: train_audio/somgre1/XC633806.ogg
#   inflating: train_audio/somgre1/XC633817.ogg
#   inflating: train_audio/somgre1/XC633827.ogg
#   inflating: train_audio/somgre1/XC633828.ogg
#   inflating: train_audio/somgre1/XC633829.ogg
#   inflating: train_audio/somgre1/XC633868.ogg
#   inflating: train_audio/somgre1/XC633893.ogg
#   inflating: train_audio/somgre1/XC633894.ogg
#   inflating: train_audio/somgre1/XC634036.ogg
#   inflating: train_audio/somgre1/XC634037.ogg
#   inflating: train_audio/somgre1/XC634040.ogg
#   inflating: train_audio/somgre1/XC634041.ogg
#   inflating: train_audio/somgre1/XC634047.ogg
#   inflating: train_audio/somgre1/XC634048.ogg
#   inflating: train_audio/somgre1/XC634089.ogg
#   inflating: train_audio/somgre1/XC634090.ogg
#   inflating: train_audio/somgre1/XC634091.ogg
#   inflating: train_audio/somgre1/XC634093.ogg
#   inflating: train_audio/somgre1/XC634203.ogg
#   inflating: train_audio/somgre1/XC634204.ogg
#   inflating: train_audio/somgre1/XC634205.ogg
#   inflating: train_audio/somgre1/XC634532.ogg
#   inflating: train_audio/somgre1/XC648493.ogg
#   inflating: train_audio/somgre1/XC650661.ogg
#   inflating: train_audio/somgre1/XC652451.ogg
#   inflating: train_audio/somgre1/XC654730.ogg
#   inflating: train_audio/somgre1/XC655042.ogg
#   inflating: train_audio/somgre1/XC655502.ogg
#   inflating: train_audio/somgre1/XC656708.ogg
#   inflating: train_audio/somgre1/XC664680.ogg
#   inflating: train_audio/somgre1/XC665001.ogg
#   inflating: train_audio/somgre1/XC667029.ogg
#   inflating: train_audio/somgre1/XC667134.ogg
#   inflating: train_audio/somgre1/XC690132.ogg
#   inflating: train_audio/somgre1/XC690133.ogg
#   inflating: train_audio/somgre1/XC701003.ogg
#   inflating: train_audio/somgre1/XC701774.ogg
#   inflating: train_audio/somgre1/XC703349.ogg
#   inflating: train_audio/somgre1/XC703350.ogg
#   inflating: train_audio/somgre1/XC718280.ogg
#   inflating: train_audio/somgre1/XC721276.ogg
#   inflating: train_audio/somgre1/XC725221.ogg
#   inflating: train_audio/somgre1/XC728971.ogg
#   inflating: train_audio/somgre1/XC756106.ogg
#   inflating: train_audio/somgre1/XC756107.ogg
#   inflating: train_audio/somtit4/XC211583.ogg
#   inflating: train_audio/somtit4/XC266412.ogg
#   inflating: train_audio/somtit4/XC266413.ogg
#   inflating: train_audio/somtit4/XC266414.ogg
#   inflating: train_audio/somtit4/XC266415.ogg
#   inflating: train_audio/somtit4/XC444560.ogg
#   inflating: train_audio/somtit4/XC444917.ogg
#   inflating: train_audio/somtit4/XC531235.ogg
#   inflating: train_audio/somtit4/XC600784.ogg
#   inflating: train_audio/somtit4/XC600785.ogg
#   inflating: train_audio/somtit4/XC600786.ogg
#   inflating: train_audio/somtit4/XC600787.ogg
#   inflating: train_audio/somtit4/XC600788.ogg
#   inflating: train_audio/somtit4/XC600789.ogg
#   inflating: train_audio/somtit4/XC600790.ogg
#   inflating: train_audio/somtit4/XC613502.ogg
#   inflating: train_audio/somtit4/XC613503.ogg
#   inflating: train_audio/somtit4/XC647024.ogg
#   inflating: train_audio/somtit4/XC728957.ogg
#   inflating: train_audio/somtit4/XC748262.ogg
#   inflating: train_audio/somtit4/XC748264.ogg
#   inflating: train_audio/somtit4/XC755914.ogg
#   inflating: train_audio/soucit1/XC119402.ogg
#   inflating: train_audio/soucit1/XC352785.ogg
#   inflating: train_audio/soucit1/XC391601.ogg
#   inflating: train_audio/soucit1/XC396039.ogg
#   inflating: train_audio/soucit1/XC396388.ogg
#   inflating: train_audio/soucit1/XC428700.ogg
#   inflating: train_audio/soucit1/XC601840.ogg
#   inflating: train_audio/soucit1/XC601841.ogg
#   inflating: train_audio/soucit1/XC602932.ogg
#   inflating: train_audio/soucit1/XC602933.ogg
#   inflating: train_audio/soucit1/XC612385.ogg
#   inflating: train_audio/soucit1/XC612386.ogg
#   inflating: train_audio/soucit1/XC613507.ogg
#   inflating: train_audio/soucit1/XC614372.ogg
#   inflating: train_audio/soucit1/XC615098.ogg
#   inflating: train_audio/soucit1/XC626072.ogg
#   inflating: train_audio/soucit1/XC627235.ogg
#   inflating: train_audio/soucit1/XC627238.ogg
#   inflating: train_audio/soucit1/XC627239.ogg
#   inflating: train_audio/soucit1/XC697678.ogg
#   inflating: train_audio/soucit1/XC703347.ogg
#   inflating: train_audio/soufis1/XC167682.ogg
#   inflating: train_audio/soufis1/XC306504.ogg
#   inflating: train_audio/soufis1/XC309835.ogg
#   inflating: train_audio/soufis1/XC326150.ogg
#   inflating: train_audio/soufis1/XC326156.ogg
#   inflating: train_audio/soufis1/XC368149.ogg
#   inflating: train_audio/soufis1/XC368392.ogg
#   inflating: train_audio/soufis1/XC383568.ogg
#   inflating: train_audio/soufis1/XC383579.ogg
#   inflating: train_audio/soufis1/XC383580.ogg
#   inflating: train_audio/soufis1/XC390391.ogg
#   inflating: train_audio/soufis1/XC395701.ogg
#   inflating: train_audio/soufis1/XC418728.ogg
#   inflating: train_audio/soufis1/XC419846.ogg
#   inflating: train_audio/soufis1/XC433035.ogg
#   inflating: train_audio/soufis1/XC433630.ogg
#   inflating: train_audio/soufis1/XC463795.ogg
#   inflating: train_audio/soufis1/XC476724.ogg
#   inflating: train_audio/soufis1/XC490661.ogg
#   inflating: train_audio/soufis1/XC496245.ogg
#   inflating: train_audio/soufis1/XC499229.ogg
#   inflating: train_audio/soufis1/XC506981.ogg
#   inflating: train_audio/soufis1/XC509740.ogg
# ...
#   inflating: train_audio/yelbis1/XC534087.ogg
#   inflating: train_audio/yelbis1/XC534090.ogg
#   inflating: train_audio/yelbis1/XC537727.ogg
#   inflating: train_audio/yelbis1/XC603438.ogg
#   inflating: train_audio/yelbis1/XC603440.ogg
#   inflating: train_audio/yelbis1/XC634554.ogg
#   inflating: train_audio/yelbis1/XC745557.ogg
#   inflating: train_audio/yenspu1/XC197819.ogg
#   inflating: train_audio/yenspu1/XC210301.ogg
#   inflating: train_audio/yenspu1/XC234438.ogg
#   inflating: train_audio/yenspu1/XC39402.ogg
#   inflating: train_audio/yenspu1/XC397668.ogg
#   inflating: train_audio/yenspu1/XC424343.ogg
#   inflating: train_audio/yenspu1/XC424436.ogg
#   inflating: train_audio/yenspu1/XC511523.ogg
#   inflating: train_audio/yenspu1/XC608924.ogg
#   inflating: train_audio/yenspu1/XC608955.ogg
#   inflating: train_audio/yenspu1/XC756890.ogg
#   inflating: train_audio/yenspu1/XC756891.ogg
#   inflating: train_audio/yertin1/XC120610.ogg
#   inflating: train_audio/yertin1/XC131665.ogg
#   inflating: train_audio/yertin1/XC156975.ogg
#   inflating: train_audio/yertin1/XC157114.ogg
#   inflating: train_audio/yertin1/XC184217.ogg
#   inflating: train_audio/yertin1/XC209744.ogg
#   inflating: train_audio/yertin1/XC234857.ogg
#   inflating: train_audio/yertin1/XC234858.ogg
#   inflating: train_audio/yertin1/XC235871.ogg
#   inflating: train_audio/yertin1/XC236859.ogg
#   inflating: train_audio/yertin1/XC239275.ogg
#   inflating: train_audio/yertin1/XC239716.ogg
#   inflating: train_audio/yertin1/XC241070.ogg
#   inflating: train_audio/yertin1/XC241071.ogg
#   inflating: train_audio/yertin1/XC241832.ogg
#   inflating: train_audio/yertin1/XC242634.ogg
#   inflating: train_audio/yertin1/XC263045.ogg
#   inflating: train_audio/yertin1/XC263610.ogg
#   inflating: train_audio/yertin1/XC265020.ogg
#   inflating: train_audio/yertin1/XC270461.ogg
#   inflating: train_audio/yertin1/XC285553.ogg
#   inflating: train_audio/yertin1/XC28683.ogg
#   inflating: train_audio/yertin1/XC289512.ogg
#   inflating: train_audio/yertin1/XC301474.ogg
#   inflating: train_audio/yertin1/XC302481.ogg
#   inflating: train_audio/yertin1/XC302482.ogg
#   inflating: train_audio/yertin1/XC302995.ogg
#   inflating: train_audio/yertin1/XC303776.ogg
#   inflating: train_audio/yertin1/XC304824.ogg
#   inflating: train_audio/yertin1/XC315995.ogg
#   inflating: train_audio/yertin1/XC323393.ogg
#   inflating: train_audio/yertin1/XC335428.ogg
#   inflating: train_audio/yertin1/XC343629.ogg
#   inflating: train_audio/yertin1/XC344992.ogg
#   inflating: train_audio/yertin1/XC356230.ogg
#   inflating: train_audio/yertin1/XC356232.ogg
#   inflating: train_audio/yertin1/XC361407.ogg
#   inflating: train_audio/yertin1/XC364475.ogg
#   inflating: train_audio/yertin1/XC364581.ogg
#   inflating: train_audio/yertin1/XC371859.ogg
#   inflating: train_audio/yertin1/XC398630.ogg
#   inflating: train_audio/yertin1/XC400471.ogg
#   inflating: train_audio/yertin1/XC401382.ogg
#   inflating: train_audio/yertin1/XC401383.ogg
#   inflating: train_audio/yertin1/XC406153.ogg
#   inflating: train_audio/yertin1/XC408464.ogg
#   inflating: train_audio/yertin1/XC419636.ogg
#   inflating: train_audio/yertin1/XC442036.ogg
#   inflating: train_audio/yertin1/XC460510.ogg
#   inflating: train_audio/yertin1/XC467158.ogg
#   inflating: train_audio/yertin1/XC467987.ogg
#   inflating: train_audio/yertin1/XC467988.ogg
#   inflating: train_audio/yertin1/XC468000.ogg
#   inflating: train_audio/yertin1/XC468001.ogg
#   inflating: train_audio/yertin1/XC476763.ogg
#   inflating: train_audio/yertin1/XC479670.ogg
#   inflating: train_audio/yertin1/XC481955.ogg
#   inflating: train_audio/yertin1/XC485191.ogg
#   inflating: train_audio/yertin1/XC487157.ogg
#   inflating: train_audio/yertin1/XC488148.ogg
#   inflating: train_audio/yertin1/XC489010.ogg
#   inflating: train_audio/yertin1/XC492366.ogg
#   inflating: train_audio/yertin1/XC498562.ogg
#   inflating: train_audio/yertin1/XC504171.ogg
#   inflating: train_audio/yertin1/XC530155.ogg
#   inflating: train_audio/yertin1/XC530239.ogg
#   inflating: train_audio/yertin1/XC539461.ogg
#   inflating: train_audio/yertin1/XC56564.ogg
#   inflating: train_audio/yertin1/XC567857.ogg
#   inflating: train_audio/yertin1/XC605848.ogg
#   inflating: train_audio/yertin1/XC608039.ogg
#   inflating: train_audio/yertin1/XC608040.ogg
#   inflating: train_audio/yertin1/XC608223.ogg
#   inflating: train_audio/yertin1/XC608590.ogg
#   inflating: train_audio/yertin1/XC620815.ogg
#   inflating: train_audio/yertin1/XC620987.ogg
#   inflating: train_audio/yertin1/XC621156.ogg
#   inflating: train_audio/yertin1/XC633669.ogg
#   inflating: train_audio/yertin1/XC633670.ogg
#   inflating: train_audio/yertin1/XC633671.ogg
#   inflating: train_audio/yertin1/XC633674.ogg
#   inflating: train_audio/yertin1/XC633675.ogg
#   inflating: train_audio/yertin1/XC633677.ogg
#   inflating: train_audio/yertin1/XC633678.ogg
#   inflating: train_audio/yertin1/XC633679.ogg
#   inflating: train_audio/yertin1/XC633680.ogg
#   inflating: train_audio/yertin1/XC633683.ogg
#   inflating: train_audio/yertin1/XC633684.ogg
#   inflating: train_audio/yertin1/XC633685.ogg
#   inflating: train_audio/yertin1/XC633687.ogg
#   inflating: train_audio/yertin1/XC633706.ogg
#   inflating: train_audio/yertin1/XC633718.ogg
#   inflating: train_audio/yertin1/XC633720.ogg
#   inflating: train_audio/yertin1/XC633721.ogg
#   inflating: train_audio/yertin1/XC633722.ogg
#   inflating: train_audio/yertin1/XC633768.ogg
#   inflating: train_audio/yertin1/XC633772.ogg
#   inflating: train_audio/yertin1/XC633774.ogg
#   inflating: train_audio/yertin1/XC633812.ogg
#   inflating: train_audio/yertin1/XC633813.ogg
#   inflating: train_audio/yertin1/XC633814.ogg
#   inflating: train_audio/yertin1/XC633815.ogg
#   inflating: train_audio/yertin1/XC633816.ogg
#   inflating: train_audio/yertin1/XC633818.ogg
#   inflating: train_audio/yertin1/XC633821.ogg
#   inflating: train_audio/yertin1/XC633838.ogg
#   inflating: train_audio/yertin1/XC633841.ogg
#   inflating: train_audio/yertin1/XC633842.ogg
#   inflating: train_audio/yertin1/XC633850.ogg
#   inflating: train_audio/yertin1/XC633858.ogg
#   inflating: train_audio/yertin1/XC633862.ogg
#   inflating: train_audio/yertin1/XC633863.ogg
#   inflating: train_audio/yertin1/XC633871.ogg
#   inflating: train_audio/yertin1/XC633892.ogg
#   inflating: train_audio/yertin1/XC634067.ogg
#   inflating: train_audio/yertin1/XC634068.ogg
#   inflating: train_audio/yertin1/XC634070.ogg
#   inflating: train_audio/yertin1/XC634071.ogg
#   inflating: train_audio/yertin1/XC634072.ogg
#   inflating: train_audio/yertin1/XC634073.ogg
#   inflating: train_audio/yertin1/XC634123.ogg
#   inflating: train_audio/yertin1/XC634144.ogg
#   inflating: train_audio/yertin1/XC634148.ogg
#   inflating: train_audio/yertin1/XC634151.ogg
#   inflating: train_audio/yertin1/XC634152.ogg
#   inflating: train_audio/yertin1/XC634155.ogg
#   inflating: train_audio/yertin1/XC634157.ogg
#   inflating: train_audio/yertin1/XC634159.ogg
#   inflating: train_audio/yertin1/XC634191.ogg
#   inflating: train_audio/yertin1/XC634196.ogg
#   inflating: train_audio/yertin1/XC634198.ogg
#   inflating: train_audio/yertin1/XC634199.ogg
#   inflating: train_audio/yertin1/XC675469.ogg
#   inflating: train_audio/yertin1/XC753425.ogg
#   inflating: train_audio/yesbar1/XC138932.ogg
#   inflating: train_audio/yesbar1/XC138933.ogg
#   inflating: train_audio/yesbar1/XC169720.ogg
#   inflating: train_audio/yesbar1/XC233336.ogg
#   inflating: train_audio/yesbar1/XC245978.ogg
#   inflating: train_audio/yesbar1/XC246010.ogg
#   inflating: train_audio/yesbar1/XC263445.ogg
#   inflating: train_audio/yesbar1/XC263449.ogg
#   inflating: train_audio/yesbar1/XC263478.ogg
#   inflating: train_audio/yesbar1/XC264914.ogg
#   inflating: train_audio/yesbar1/XC267371.ogg
#   inflating: train_audio/yesbar1/XC281973.ogg
#   inflating: train_audio/yesbar1/XC353565.ogg
#   inflating: train_audio/yesbar1/XC360423.ogg
#   inflating: train_audio/yesbar1/XC395749.ogg
#   inflating: train_audio/yesbar1/XC397057.ogg
#   inflating: train_audio/yesbar1/XC400182.ogg
#   inflating: train_audio/yesbar1/XC400183.ogg
#   inflating: train_audio/yesbar1/XC400460.ogg
#   inflating: train_audio/yesbar1/XC419616.ogg
#   inflating: train_audio/yesbar1/XC468004.ogg
#   inflating: train_audio/yesbar1/XC468005.ogg
#   inflating: train_audio/yesbar1/XC468006.ogg
#   inflating: train_audio/yesbar1/XC468007.ogg
#   inflating: train_audio/yesbar1/XC482165.ogg
#   inflating: train_audio/yesbar1/XC482167.ogg
#   inflating: train_audio/yesbar1/XC503400.ogg
#   inflating: train_audio/yesbar1/XC503401.ogg
#   inflating: train_audio/yesbar1/XC700474.ogg
#   inflating: train_audio/yespet1/XC208439.ogg
#   inflating: train_audio/yespet1/XC294872.ogg
#   inflating: train_audio/yespet1/XC363499.ogg
#   inflating: train_audio/yespet1/XC364377.ogg
#   inflating: train_audio/yespet1/XC392980.ogg
#   inflating: train_audio/yespet1/XC393627.ogg
#   inflating: train_audio/yespet1/XC602617.ogg
#   inflating: train_audio/yespet1/XC602618.ogg
#   inflating: train_audio/yespet1/XC602619.ogg
#   inflating: train_audio/yespet1/XC605080.ogg
#   inflating: train_audio/yespet1/XC610331.ogg
#   inflating: train_audio/yespet1/XC627250.ogg
#   inflating: train_audio/yespet1/XC630279.ogg
#   inflating: train_audio/yespet1/XC692101.ogg
#   inflating: train_audio/yespet1/XC697686.ogg
#   inflating: train_audio/yetgre1/XC247367.ogg
#   inflating: train_audio/yetgre1/XC247369.ogg
#   inflating: train_audio/yetgre1/XC282051.ogg
#   inflating: train_audio/yetgre1/XC289493.ogg
#   inflating: train_audio/yetgre1/XC338717.ogg
#   inflating: train_audio/yetgre1/XC339708.ogg
#   inflating: train_audio/yetgre1/XC344194.ogg
#   inflating: train_audio/yetgre1/XC344251.ogg
#   inflating: train_audio/yetgre1/XC346069.ogg
#   inflating: train_audio/yetgre1/XC349660.ogg
#   inflating: train_audio/yetgre1/XC349661.ogg
#   inflating: train_audio/yetgre1/XC370962.ogg
#   inflating: train_audio/yetgre1/XC373426.ogg
#   inflating: train_audio/yetgre1/XC403259.ogg
#   inflating: train_audio/yetgre1/XC403543.ogg
#   inflating: train_audio/yetgre1/XC405750.ogg
#   inflating: train_audio/yetgre1/XC475334.ogg
#   inflating: train_audio/yetgre1/XC498853.ogg
#   inflating: train_audio/yetgre1/XC498854.ogg
#   inflating: train_audio/yetgre1/XC530126.ogg
#   inflating: train_audio/yetgre1/XC530241.ogg
#   inflating: train_audio/yetgre1/XC530242.ogg
#   inflating: train_audio/yetgre1/XC574557.ogg
#   inflating: train_audio/yetgre1/XC574558.ogg
#   inflating: train_audio/yetgre1/XC574559.ogg
#   inflating: train_audio/yetgre1/XC667564.ogg
#   inflating: train_audio/yetgre1/XC716763.ogg
#   inflating: train_audio/yewgre1/XC113255.ogg
#   inflating: train_audio/yewgre1/XC113256.ogg
#   inflating: train_audio/yewgre1/XC113435.ogg
#   inflating: train_audio/yewgre1/XC120611.ogg
#   inflating: train_audio/yewgre1/XC122417.ogg
#   inflating: train_audio/yewgre1/XC126589.ogg
#   inflating: train_audio/yewgre1/XC126612.ogg
#   inflating: train_audio/yewgre1/XC131906.ogg
#   inflating: train_audio/yewgre1/XC144141.ogg
#   inflating: train_audio/yewgre1/XC157118.ogg
#   inflating: train_audio/yewgre1/XC163357.ogg
#   inflating: train_audio/yewgre1/XC164153.ogg
#   inflating: train_audio/yewgre1/XC18465.ogg
#   inflating: train_audio/yewgre1/XC201221.ogg
#   inflating: train_audio/yewgre1/XC205780.ogg
#   inflating: train_audio/yewgre1/XC209729.ogg
#   inflating: train_audio/yewgre1/XC233084.ogg
#   inflating: train_audio/yewgre1/XC233785.ogg
#   inflating: train_audio/yewgre1/XC234851.ogg
#   inflating: train_audio/yewgre1/XC234853.ogg
#   inflating: train_audio/yewgre1/XC234854.ogg
#   inflating: train_audio/yewgre1/XC235869.ogg
#   inflating: train_audio/yewgre1/XC235870.ogg
#   inflating: train_audio/yewgre1/XC235944.ogg
#   inflating: train_audio/yewgre1/XC235945.ogg
#   inflating: train_audio/yewgre1/XC235946.ogg
#   inflating: train_audio/yewgre1/XC235947.ogg
#   inflating: train_audio/yewgre1/XC236324.ogg
#   inflating: train_audio/yewgre1/XC236845.ogg
#   inflating: train_audio/yewgre1/XC236846.ogg
#   inflating: train_audio/yewgre1/XC236847.ogg
#   inflating: train_audio/yewgre1/XC236857.ogg
#   inflating: train_audio/yewgre1/XC236865.ogg
#   inflating: train_audio/yewgre1/XC236870.ogg
#   inflating: train_audio/yewgre1/XC236966.ogg
#   inflating: train_audio/yewgre1/XC237453.ogg
#   inflating: train_audio/yewgre1/XC237454.ogg
#   inflating: train_audio/yewgre1/XC239970.ogg
#   inflating: train_audio/yewgre1/XC240502.ogg
#   inflating: train_audio/yewgre1/XC240503.ogg
#   inflating: train_audio/yewgre1/XC246126.ogg
#   inflating: train_audio/yewgre1/XC246128.ogg
#   inflating: train_audio/yewgre1/XC263443.ogg
#   inflating: train_audio/yewgre1/XC265799.ogg
#   inflating: train_audio/yewgre1/XC266006.ogg
#   inflating: train_audio/yewgre1/XC284889.ogg
#   inflating: train_audio/yewgre1/XC284895.ogg
#   inflating: train_audio/yewgre1/XC287948.ogg
#   inflating: train_audio/yewgre1/XC293991.ogg
#   inflating: train_audio/yewgre1/XC298398.ogg
#   inflating: train_audio/yewgre1/XC301453.ogg
#   inflating: train_audio/yewgre1/XC301602.ogg
#   inflating: train_audio/yewgre1/XC301603.ogg
#   inflating: train_audio/yewgre1/XC302981.ogg
#   inflating: train_audio/yewgre1/XC302982.ogg
#   inflating: train_audio/yewgre1/XC309411.ogg
#   inflating: train_audio/yewgre1/XC318287.ogg
#   inflating: train_audio/yewgre1/XC325878.ogg
#   inflating: train_audio/yewgre1/XC336100.ogg
#   inflating: train_audio/yewgre1/XC343780.ogg
#   inflating: train_audio/yewgre1/XC344996.ogg
#   inflating: train_audio/yewgre1/XC347627.ogg
#   inflating: train_audio/yewgre1/XC365413.ogg
#   inflating: train_audio/yewgre1/XC371862.ogg
#   inflating: train_audio/yewgre1/XC374341.ogg
#   inflating: train_audio/yewgre1/XC396379.ogg
#   inflating: train_audio/yewgre1/XC397065.ogg
#   inflating: train_audio/yewgre1/XC397066.ogg
#   inflating: train_audio/yewgre1/XC397164.ogg
#   inflating: train_audio/yewgre1/XC397165.ogg
#   inflating: train_audio/yewgre1/XC397563.ogg
#   inflating: train_audio/yewgre1/XC397731.ogg
#   inflating: train_audio/yewgre1/XC397732.ogg
#   inflating: train_audio/yewgre1/XC399131.ogg
#   inflating: train_audio/yewgre1/XC399734.ogg
#   inflating: train_audio/yewgre1/XC400185.ogg
#   inflating: train_audio/yewgre1/XC400186.ogg
#   inflating: train_audio/yewgre1/XC400188.ogg
#   inflating: train_audio/yewgre1/XC401866.ogg
#   inflating: train_audio/yewgre1/XC401867.ogg
#   inflating: train_audio/yewgre1/XC401892.ogg
#   inflating: train_audio/yewgre1/XC429112.ogg
#   inflating: train_audio/yewgre1/XC429122.ogg
#   inflating: train_audio/yewgre1/XC432176.ogg
#   inflating: train_audio/yewgre1/XC470576.ogg
#   inflating: train_audio/yewgre1/XC476762.ogg
#   inflating: train_audio/yewgre1/XC478540.ogg
#   inflating: train_audio/yewgre1/XC479059.ogg
#   inflating: train_audio/yewgre1/XC479061.ogg
#   inflating: train_audio/yewgre1/XC48477.ogg
#   inflating: train_audio/yewgre1/XC487128.ogg
#   inflating: train_audio/yewgre1/XC505815.ogg
#   inflating: train_audio/yewgre1/XC506518.ogg
#   inflating: train_audio/yewgre1/XC513865.ogg
#   inflating: train_audio/yewgre1/XC514644.ogg
#   inflating: train_audio/yewgre1/XC530236.ogg
#   inflating: train_audio/yewgre1/XC537944.ogg
#   inflating: train_audio/yewgre1/XC617114.ogg
#   inflating: train_audio/yewgre1/XC641613.ogg
#   inflating: train_audio/yewgre1/XC675466.ogg
#   inflating: train_audio/yewgre1/XC675467.ogg
#   inflating: train_audio/yewgre1/XC700545.ogg
#   inflating: train_audio/yewgre1/XC700615.ogg
#   inflating: train_audio/yewgre1/XC703472.ogg
#   inflating: train_audio/yewgre1/XC703485.ogg
#   inflating: train_audio/yewgre1/XC704433.ogg
#   inflating: train_audio/yewgre1/XC752974.ogg
#   inflating: train_audio/yewgre1/XC753190.ogg
#   inflating: train_metadata.csv

# %%
# contents of train_audio
audio_data_dir = 'train_audio/'
# train_metadata.csv
csv_file = 'train_metadata.csv'
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Create a dictionary that maps class labels to numerical labels
data = pd.read_csv(csv_file)
labels_arr = data['primary_label']
class_to_index = {class_label: index for index, class_label in enumerate(labels_arr)}

# %%
# Get all unique labels from csv
unique_values = set()
# Initialize the label encoder
label_encoder = LabelEncoder()


# Open the CSV file and read unique values from a specific column (e.g., column index 0)
with open(csv_file, 'r') as csvfile:
    csvreader = csv.reader(csvfile)

    # Skip header row if it exists
    next(csvreader, None)

    # Iterate through rows and extract unique values from a specific column
    for row in csvreader:
        # Assuming the column index is 0 (change it to the appropriate index)
        column_value = row[0].strip()  # Use .strip() to remove leading/trailing whitespaces

        # Add the value to the set
        if column_value not in unique_values:
            unique_values.add(column_value)

# Convert the set to a list before applying fit_transform
unique_values_list = list(unique_values)
# Create a dictionary mapping string labels to numbers from 0 to 263
label_to_number_mapping = {label: index for index, label in enumerate(unique_values_list)}
print('mapped_values',label_to_number_mapping)
# Fit and transform the labels to numerical values
# encoded_labels = label_encoder.fit_transform(unique_values_list)
# print('Encoded Labels:', label_to_number_mapping)
# Out:
# mapped_values {'pygbat1': 0, 'wtbeat1': 1, 'blksaw1': 2, 'yebsto1': 3, 'raybar1': 4, 'fatrav1': 5, 'yesbar1': 6, 'kvbsun1': 7, 'woosan': 8, 'norpuf1': 9, 'ratcis1': 10, 'reccor': 11, 'abethr1': 12, 'stusta1': 13, 'yefcan': 14, 'afrgos1': 15, 'palfly2': 16, 'vilwea1': 17, 'lawgol': 18, 'reboxp1': 19, 'whbcro2': 20, 'libeat1': 21, 'comsan': 22, 'yeccan1': 23, 'rocmar2': 24, 'bcbeat1': 25, 'reftin1': 26, 'supsta1': 27, 'gnbcam2': 28, 'thrnig1': 29, 'bkfruw1': 30, 'spemou2': 31, 'crheag1': 32, 'blwlap1': 33, 'chibat1': 34, 'affeag1': 35, 'rehwea1': 36, 'nubwoo1': 37, 'wbrcha2': 38, 'gyhspa1': 39, 'eubeat1': 40, 'squher1': 41, 'brobab1': 42, 'fislov1': 43, 'yebere1': 44, 'ndcsun2': 45, 'scrcha1': 46, 'yebduc1': 47, 'cibwar1': 48, 'blfbus1': 49, 'amesun2': 50, 'whihel1': 51, 'bswdov1': 52, 'blhher1': 53, 'bawhor2': 54, 'rebhor1': 55, 'abhori1': 56, 'grwpyt1': 57, 'darbar1': 58, 'bawman1': 59, 'brcwea1': 60, 'rewsta1': 61, 'lotlap1': 62, 'lessts1': 63, 'rbsrob1': 64, 'wheslf1': 65, 'sichor1': 66, 'kerspa2': 67, 'afghor1': 68, 'brcsta1': 69, 'egygoo': 70, 'huncis1': 71, 'sccsun2': 72, 'yertin1': 73, 'tamdov1': 74, 'grywrw1': 75, 'chtapa3': 76, 'loceag1': 77, 'soucit1': 78, 'afpwag1': 79, 'gryapa1': 80, 'tacsun1': 81, 'whbwhe3': 82, 'chespa1': 83, 'norcro1': 84, 'afpfly1': 85, 'spmthr1': 86, 'norbro1': 87, 'reisee2': 88, 'trobou1': 89, 'broman1': 90, 'augbuz1': 91, 'edcsun3': 92, 'helgui': 93, 'golher1': 94, 'vimwea1': 95, 'blakit1': 96, 'whbwea1': 97, 'moccha1': 98, 'whhsaw1': 99, 'refbar2': 100, 'gobbun1': 101, 'brubru1': 102, 'litswi1': 103, 'hamerk1': 104, 'scthon1': 105, 'blnmou1': 106, 'litwea1': 107, 'brrwhe3': 108, 'gyhneg1': 109, 'afgfly1': 110, 'bltbar1': 111, 'cohmar1': 112, 'norfis1': 113, 'chewea1': 114, 'macshr1': 115, 'sincis1': 116, 'litegr': 117, 'yespet1': 118, 'eaywag1': 119, 'carcha1': 120, 'gargan': 121, 'gyhbus1': 122, 'afrgrp1': 123, 'afrjac1': 124, 'colsun2': 125, 'blbpuf2': 126, 'nobfly1': 127, 'witswa1': 128, 'afecuc1': 129, 'whctur2': 130, 'sobfly1': 131, 'palpri1': 132, 'malkin1': 133, 'spfbar1': 134, 'blhgon1': 135, 'combul2': 136, 'refcro1': 137, 'bubwar2': 138, 'lotcor1': 139, 'rebfir2': 140, 'vibsta2': 141, 'spwlap1': 142, 'fatwid1': 143, 'gytbar1': 144, 'whrshr1': 145, 'bltori1': 146, 'piecro1': 147, 'shesta1': 148, 'butapa1': 149, 'grewoo2': 150, 'brtcha1': 151, 'sacibi2': 152, 'reccuc1': 153, 'equaka1': 154, 'slbgre1': 155, 'mabeat1': 156, 'dotbar1': 157, 'gobsta5': 158, 'wlwwar': 159, 'brcale1': 160, 'pabspa1': 161, 'grccra1': 162, 'categr': 163, 'combuz1': 164, 'mouwag1': 165, 'gobwea1': 166, 'gybfis1': 167, 'sltnig1': 168, 'yelbis1': 169, 'whcpri2': 170, 'blaplo1': 171, 'gabgos2': 172, 'grbcam1': 173, 'fotdro5': 174, 'blcapa2': 175, 'marsto1': 176, 'grecor': 177, 'yebbar1': 178, 'darter3': 179, 'tafpri1': 180, 'blacuc1': 181, 'strsee1': 182, 'barswa': 183, 'brwwar1': 184, 'brctch1': 185, 'marsun2': 186, 'afdfly1': 187, 'gbesta1': 188, 'gyhkin1': 189, 'btweye2': 190, 'pitwhy': 191, 'reedov1': 192, 'rindov': 193, 'soufis1': 194, 'walsta1': 195, 'quailf1': 196, 'wbswea1': 197, 'yebgre1': 198, 'wfbeat1': 199, 'rufcha2': 200, 'spfwea1': 201, 'dutdov1': 202, 'klacuc1': 203, 'purgre2': 204, 'rerswa1': 205, 'blnwea1': 206, 'bltapa1': 207, 'crohor1': 208, 'afbfly1': 209, 'whbtit5': 210, 'crefra2': 211, 'gnhsun1': 212, 'brosun1': 213, 'hartur1': 214, 'strher': 215, 'varsun2': 216, 'afrthr1': 217, 'yetgre1': 218, 'rostur1': 219, 'chucis1': 220, 'meypar1': 221, 'hunsun2': 222, 'beasun2': 223, 'spepig1': 224, 'subbus1': 225, 'brican1': 226, 'piekin1': 227, 'rehblu1': 228, 'joygre1': 229, 'lesmaw1': 230, 'slcbou1': 231, 'greegr': 232, 'luebus1': 233, 'whbcan1': 234, 'whbcou1': 235, 'easmog1': 236, 'wbgbir1': 237, 'cabgre1': 238, 'wookin1': 239, 'carwoo1': 240, 'yebapa1': 241, 'hipbab1': 242, 'yenspu1': 243, 'hadibi1': 244, 'somgre1': 245, 'blacra1': 246, 'somtit4': 247, 'abythr1': 248, 'afpkin1': 249, 'afmdov1': 250, 'bkctch1': 251, 'didcuc1': 252, 'laudov1': 253, 'eswdov1': 254, 'gycwar3': 255, 'ruegls1': 256,  ...

# %%
##TODO Define Modell for Classification
##TODO Make the MelSpectograms the same length
class AudioClassifier(pl.LightningModule):
    def __init__(self, num_classes):
        super(AudioClassifier, self).__init__()

        self.conv1 = nn.Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
        self.conv2 = nn.Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
        self.conv3 = nn.Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))

        self.pool = nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2))

        self.fc1 = nn.Linear(256 * 16 * 78, 512)  # Adjust input size based on your spectrogram size
        self.fc2 = nn.Linear(512, 264)

        self.dropout = nn.Dropout(0.5)


    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))

        #print('x0',x.size(0))
        #print('x1',x.size(1))
        #print('x2',x.size(2))
        num_features = x.size(0) * x.size(1) * x.size(2)
        x = x.view(-1, num_features)  # Reshape based on the calculated number of features

        x = self.fc1(x)
        x = self.fc2(x)

        return x

    def training_step(self, batch, batch_idx):
        x, y = batch
        y_pred = self(x)
        #print('predicted',y_pred)

        # Calculate the train loss
        loss = F.cross_entropy(y_pred, y)

        # Calculate train accuracy
        accuracy = torch.sum(torch.argmax(y_pred, dim=1) == y).item() / y.size(0)

        self.log('train_loss', loss, on_epoch=True)
        self.log('train_accuracy', accuracy, on_epoch=True)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        y_pred = self(x)

        # Calculate the validation loss
        loss = F.cross_entropy(y_pred, y)

        # Calculate validation accuracy
        accuracy = torch.sum(torch.argmax(y_pred, dim=1) == y).item() / y.size(0)

        # Log validation loss and accuracy
        self.log('val_loss', loss, on_epoch=True)  # Log loss at each step
        self.log('val_accuracy', accuracy, on_epoch=True)  # Log accuracy at each step

        return loss
        pass


    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=0.0001,weight_decay=0.0001)

# %%
def transformAudio(audio, sample_rate):
    # Compute the Mel spectrogram
    n_fft = 1024  # Size of the FFT window
    hop_length = 256  # Hop size for spectrogram frames
    n_mels = 128  # Number of Mel filterbanks
    segment_duration = 5.0  # egy segment hossza
    mel_start_freq = 40.0
    mel_end_freq = 15000
    # durationFile = 20 # 0.5min
    durationFile = librosa.get_duration(y=audio, sr=32000)
    audio_segments_arr = []

    durationFileInSamples = int(durationFile * 32000)
    segmentDurationInSamples = int(segment_duration * 32000)

    for startSample in range(0, durationFileInSamples, segmentDurationInSamples):
        endSample = startSample + segmentDurationInSamples

        sampleVec = audio[startSample:endSample]

        # Get mel spectrogram
        melSpec = librosa.feature.melspectrogram(y=sampleVec, sr=32000, n_fft=n_fft,
                                                 hop_length=hop_length, n_mels=n_mels, fmin=mel_start_freq,
                                                 fmax=mel_end_freq, power=2.0)

        # Convert to decibels (log-scale)
        mel_spec_db = librosa.power_to_db(melSpec, ref=np.max, top_db=100)
        nLowFreqsInPixelToCut = int(2 / 2.0)
        nHighFreqsInPixelToCut = int(4 / 2.0)

        # if nHighFreqsInPixelToCut:
        #     mel_spec_db = mel_spec_db[nLowFreqsInPixelToCut:-nHighFreqsInPixelToCut]
        # else:
        #     mel_spec_db = mel_spec_db[nLowFreqsInPixelToCut:]

        # Normalize values between 0 and 1 (& prevent divide by zero)
        mel_spec_db -= mel_spec_db.min()
        melSpecMax = mel_spec_db.max()
        if melSpecMax:
            melSpec /= melSpecMax

        maxVal = 255.9
        mel_spec_db *= maxVal
        mel_spec_db = maxVal - mel_spec_db
        audio_segments_arr.append(mel_spec_db)

        # # Resize
        # specImagePil = Image.fromarray(melSpec.astype(np.uint8))
        # specImagePil = specImagePil.resize(imageSize, interpolationMethod)
        #
        # # Expand to 3 channels
        # specImage = specImagePil.convert('RGB')
        # plt.imshow(specImage)
        # plt.axis('off')  # Turn off axis labels and ticks
        # plt.show()

        # Visualize the Mel spectrogram
        # plt.figure(figsize=(10, 4))
        # librosa.display.specshow(mel_spec_db, x_axis='time', y_axis='mel', sr=sample_rate, hop_length=hop_length,
        #                          cmap='viridis')
        # plt.colorbar(format='%+2.0f dB')
        # plt.title('Mel Spectrogram')
        # plt.show()

    # exit()

    # [x,y] 1D n_mels = 128 2D audio_length
    return audio_segments_arr

# %%
# Define a function to resize a Mel spectrogram to a target shape
def resize_mel_spectrogram(mel_spec, target_shape):
    return scipy.ndimage.zoom(mel_spec, (1, target_shape / mel_spec.shape[1]))

# %%
class AudioClassificationDataset(Dataset):
    def __init__(self, data_dir, csv_file, transform=None, shuffle=False, batch_size=10):
        self.data_dir = data_dir
        self.csv_file = csv_file
        self.transform = transform
        self.audio_data_filename_arr = []
        self.labels = []
        self.data = self._load_data()
        self.shuffle = shuffle
        self.batch_size = batch_size

    # Itt tortenik a labelek es a hozzajuk tartozo fileok kiszedese a csv segitsegevel
    def _load_data(self):
        data = pd.read_csv(self.csv_file)
        # labels_arr = data['primary_label']
        self.audio_data_filename_arr = data['filename']

        return self.audio_data_filename_arr

    def __len__(self):
        return len(self.audio_data_filename_arr)

    def __getitem__(self, idx):
        fixed_size = 30
        ##TODO file does not exist check
        audio_file = os.path.join(audio_data_dir, self.audio_data_filename_arr[idx])
        #print('audiofile', audio_file)
        self.labels = self.data.iloc[idx].split('/')[0]
        # print('label',self.labels)

        waveform, sample_rate = librosa.load(audio_file, sr=None)

        melSpectogram = transformAudio(waveform, sample_rate)

        # Apply fixed size padding or trimming to each array in the list
        for i in range(len(melSpectogram)):
            # Ensure that each segment has the default shape (128, 626)
            if melSpectogram[i].shape != 626:
                melSpectogram[i] = resize_mel_spectrogram(melSpectogram[i], 626)
            mel_spec_db_tensor = torch.from_numpy(melSpectogram[i])
            mel_spec_db_tensor = mel_spec_db_tensor.unsqueeze(0)

            class_label = self.data.iloc[idx].split('/')[0]
            #print('label:', class_label)

            # Convert the class label to a numerical label
            label_variable = label_to_number_mapping.get(class_label, -1)
            #print('converted',converted_labels)
            label_tensor = torch.tensor(label_variable, dtype=torch.long)  # Use torch.float32 for regression tasks
            #print('Len of trimmed or padded melspec:', melSpectogram[0].shape)
            #print('MelSpecShape',mel_spec_db_tensor.size())

        #print('melTensor',mel_spec_db_tensor.size())
        #print('labelTensor',label_tensor.repeat(mel_spec_db_tensor.size(0)))
        return mel_spec_db_tensor, label_tensor.repeat(mel_spec_db_tensor.size(0))

# %%
# Create an instance of your custom dataset
batch_size = 32
dataset = AudioClassificationDataset(audio_data_dir, csv_file, shuffle=True, batch_size=batch_size)

# Define train, validation, and test split ratios
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Calculate the number of samples for each split
num_samples = len(dataset)
num_train = int(train_ratio * num_samples)
num_val = int(val_ratio * num_samples)
num_test = num_samples - num_train - num_val

# Randomly shuffle the dataset
indices = list(range(num_samples))
random.shuffle(indices)

# Split the dataset
train_indices = indices[:num_train]
val_indices = indices[num_train:num_train + num_val]
test_indices = indices[-num_test:]

# Create data loaders for train, validation, and test sets
train_sampler = torch.utils.data.SubsetRandomSampler(train_indices)
val_sampler = torch.utils.data.SubsetRandomSampler(val_indices)
test_sampler = torch.utils.data.SubsetRandomSampler(test_indices)

# Adjust as needed
train_loader = DataLoader(dataset, batch_size=batch_size, sampler=train_sampler)
val_loader = DataLoader(dataset, batch_size=batch_size, sampler=val_sampler)
test_loader = DataLoader(dataset, batch_size=batch_size, sampler=test_sampler)

num_classes = 263  # Set the number of classes
model = AudioClassifier(num_classes=num_classes)

checkpoint_callback = ModelCheckpoint(
    save_top_k=1,
    mode='min',
    filename='best_model',
    verbose=True,
    save_weights_only=True,
)

trainer = pl.Trainer(max_epochs=10, callbacks=[checkpoint_callback])
trainer.fit(model,train_loader.dataset,val_loader.dataset)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name    | Type      | Params
# --------------------------------------
# 0 | conv1   | Conv2d    | 640
# 1 | conv2   | Conv2d    | 73.9 K
# 2 | conv3   | Conv2d    | 295 K
# 3 | pool    | MaxPool2d | 0
# 4 | fc1     | Linear    | 163 M
# 5 | fc2     | Linear    | 135 K
# 6 | dropout | Dropout   | 0
# --------------------------------------
# 164 M     Trainable params
# 0         Non-trainable params
# 164 M     Total params
# 656.334   Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=940
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=627
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=512
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=256
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=470
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=768
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=287
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=416
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=480
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=640
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=128
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=993
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=653
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=313
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=157
#   warnings.warn(

# %%
# Define a function to calculate accuracy
def calculate_accuracy(outputs, labels):
    _, predicted = torch.max(outputs, 1)
    correct = (predicted == labels).sum().item()
    accuracy = correct / labels.size(0)
    return accuracy

# %%
# Create a DataLoader to batch and shuffle the data
batch_size = 32
learning_rate = 0.001
num_epochs = 10
# dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Create an instance of the AudioClassifier model
num_classes = 263  # Set the number of classes
model = AudioClassifier(num_classes=num_classes)

# Print the model architecture
print(model)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Define device (GPU or CPU)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)
#print('here', train_loader)
# exit()

# %%
#torch.cuda.synchronize()
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0

    for batch_idx, (mel_spectrograms, labels) in enumerate(train_loader):
        #print('MelSpecsShape',mel_spectrograms.size())
        #print('Label',labels)
        mel_spectrograms = mel_spectrograms.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()  # Zero the gradients

        # Forward pass
        outputs = model(mel_spectrograms)

        # Flatten the outputs and labels for computing the loss
        outputs = outputs.view(outputs.size(0), -1)
        labels = labels.view(labels.size(0))
        #print('output',outputs)
        #print('labs',labels)

        # Compute the loss
        loss = criterion(outputs, labels)

        # Backpropagation
        loss.backward()

        # Update model weights
        optimizer.step()

        running_loss += loss.item()

        # Print mini-batch statistics
        print(f"Batch [{epoch + 1}/{num_epochs}], Step [{batch_idx + 1}/{len(train_loader)}], Loss: {loss.item():.4f}")

    # Print average loss for the epoch
    average_loss = running_loss / len(train_loader)
    print(f"Epoch [{epoch + 1}/{num_epochs}] - Loss: {average_loss:.4f}")

    model.eval()  # Set the model to evaluation mode
    val_loss = 0.0
    total_accuracy = 0.0

    # Validation run
    with torch.no_grad():  # Disable gradient calculation for validation
        for batch_idx, (mel_spectrograms, labels) in enumerate(val_loader):
            mel_spectrograms = mel_spectrograms.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(mel_spectrograms)
            outputs = outputs.view(outputs.size(0), -1)
            labels = labels.view(labels.size(0))
            #print('Outputs size',outputs.size())
            #print('Labels size',labels.size())

            # Compute validation loss
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            # Calculate accuracy
            accuracy = calculate_accuracy(outputs, labels)
            total_accuracy += accuracy

    # Average validation loss and accuracy over the validation dataset
    avg_val_loss = val_loss / len(val_loader)
    avg_accuracy = total_accuracy / len(val_loader)

    # Print validation statistics
    print(f"Validation - Epoch [{epoch + 1}/{num_epochs}], Loss: {avg_val_loss:.4f}, Accuracy: {avg_accuracy:.4f}")
    # Save the trained model (optional)
    torch.save(model.state_dict(), 'audio_classifier_model.pth')

# Save the trained model (optional)
torch.save(model.state_dict(), 'audio_classifier_model.pth')
